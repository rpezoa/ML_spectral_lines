# %% [markdown]
# # Generation of training and testing data from models
# ****
# - Data source: Dr. Michel Curé and Catalina Arcos, IFA UV
# - Each model is stored in a file with a name like: "t4000g20v10.dat", where
#  - t is the effective temperature: 4000 [K]
#  - g is 10 times the logarithm of the gravity in [cm/seg^2]: 20/10 = 2.0
#  - v_rot is the rotational velocity in [km/seg]: 10
#
# - For this analysis we will consider:
#  - v_rot >= 100
#  - t_eff >= 15000
#  - wavelength range [4460, 4480]
#
# - Note that the y axis is the normalized flux

# %% [markdown]
# ## Needed libraries

# %%
import glob
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import shutil

from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Functions

# %%
def string2params(string, show=True):
    s1 = string.partition("g")
    t = s1[0][1:]
    s2 = s1[2].partition("v")
    g = s2[0]
    v = s2[-1]
    if show:
        print(s1)
        print("t:",t)
        print(s2)
        print("g: ",float(g)/10)
        print("v:", v)
    return float(t), float(g)/10, float(v)

# %% [markdown]
# ## Files list

# %%
files = glob.glob('filtered_wv_models/*')
m = len(files)
print("Number of files in models", m)
print("5 first files: \n", files[0:5])
# Out:
# Number of files in models 5425
# 5 first files:
#  ['filtered_wv_models/f_t35000g20v280.dat', 'filtered_wv_models/f_t20000g20v260.dat', 'filtered_wv_models/f_t28000g20v350.dat', 'filtered_wv_models/f_t17000g30v170.dat', 'filtered_wv_models/f_t19000g45v220.dat']

# %% [markdown]
# ## Building X an y matrices
# *****

# %%
print("--> X has dimension", m, " x 201")
print("--> y has diemsnion", m, " x 3")

y = np.zeros((m,3))
df = pd.read_csv(files[0], sep=" ", header=None)
x_points = df[0].values
n_points, n_columns = df.shape
display(df[1].values.shape)
print("Num. of points in x axis: ", n_points)
# Out:
# --> X has dimension 5425  x 201
# --> y has diemsnion 5425  x 3
# (201,)
# Num. of points in x axis:  201

# %%
# X matrix contains the spectral lines
X = np.zeros((m,n_points))
# y matrix contains the labels of each spectral line
y = np.zeros((m,3))
for i,name in enumerate(files):
    file_name = name.split("/")[-1].split(".")[0]
    print(file_name)
    df = pd.read_csv(name, sep=" ", header=None)
    print(file_name.split("_")[1])
    t,g,v = string2params(file_name.split("_")[1])
    X[i,:] = df[1].values
    y[i] = t,g,v
    #print("----")
# Out:
# f_t35000g20v280
# t35000g20v280
# ('t35000', 'g', '20v280')
# t: 35000
# ('20', 'v', '280')
# g:  2.0
# v: 280
# f_t20000g20v260
# t20000g20v260
# ('t20000', 'g', '20v260')
# t: 20000
# ('20', 'v', '260')
# g:  2.0
# v: 260
# f_t28000g20v350
# t28000g20v350
# ('t28000', 'g', '20v350')
# t: 28000
# ('20', 'v', '350')
# g:  2.0
# v: 350
# f_t17000g30v170
# t17000g30v170
# ('t17000', 'g', '30v170')
# t: 17000
# ('30', 'v', '170')
# g:  3.0
# v: 170
# f_t19000g45v220
# t19000g45v220
# ('t19000', 'g', '45v220')
# t: 19000
# ('45', 'v', '220')
# g:  4.5
# v: 220
# f_t30000g45v230
# t30000g45v230
# ('t30000', 'g', '45v230')
# t: 30000
# ('45', 'v', '230')
# g:  4.5
# v: 230
# f_t38000g45v300
# t38000g45v300
# ('t38000', 'g', '45v300')
# t: 38000
# ('45', 'v', '300')
# g:  4.5
# v: 300
# f_t17000g20v170
# t17000g20v170
# ('t17000', 'g', '20v170')
# t: 17000
# ('20', 'v', '170')
# g:  2.0
# v: 170
# f_t20000g30v260
# t20000g30v260
# ('t20000', 'g', '30v260')
# t: 20000
# ('30', 'v', '260')
# g:  3.0
# v: 260
# f_t35000g30v280
# t35000g30v280
# ('t35000', 'g', '30v280')
# t: 35000
# ('30', 'v', '280')
# g:  3.0
# v: 280
# f_t28000g30v350
# t28000g30v350
# ('t28000', 'g', '30v350')
# t: 28000
# ('30', 'v', '350')
# g:  3.0
# v: 350
# f_t22000g25v110
# t22000g25v110
# ('t22000', 'g', '25v110')
# t: 22000
# ('25', 'v', '110')
# g:  2.5
# v: 110
# f_t34000g35v320
# t34000g35v320
# ('t34000', 'g', '35v320')
# t: 34000
# ('35', 'v', '320')
# g:  3.5
# v: 320
# f_t15000g35v200
# t15000g35v200
# ('t15000', 'g', '35v200')
# t: 15000
# ('35', 'v', '200')
# g:  3.5
# v: 200
# f_t31000g50v390
# t31000g50v390
# ('t31000', 'g', '50v390')
# t: 31000
# ('50', 'v', '390')
# g:  5.0
# v: 390
# f_t18000g50v380
# t18000g50v380
# ('t18000', 'g', '50v380')
# t: 18000
# ('50', 'v', '380')
# g:  5.0
# v: 380
# f_t24000g50v370
# t24000g50v370
# ('t24000', 'g', '50v370')
# t: 24000
# ('50', 'v', '370')
# g:  5.0
# v: 370
# f_t32000g40v140
# t32000g40v140
# ('t32000', 'g', '40v140')
# t: 32000
# ('40', 'v', '140')
# g:  4.0
# v: 140
# f_t34000g25v320
# t34000g25v320
# ('t34000', 'g', '25v320')
# t: 34000
# ('25', 'v', '320')
# g:  2.5
# v: 320
# f_t15000g25v200
# t15000g25v200
# ('t15000', 'g', '25v200')
# t: 15000
# ('25', 'v', '200')
# g:  2.5
# v: 200
# f_t36000g45v400
# t36000g45v400
# ('t36000', 'g', '45v400')
# t: 36000
# ('45', 'v', '400')
# g:  4.5
# v: 400
# f_t22000g35v110
# t22000g35v110
# ('t22000', 'g', '35v110')
# t: 22000
# ('35', 'v', '110')
# g:  3.5
# v: 110
# f_t32000g50v140
# t32000g50v140
# ('t32000', 'g', '50v140')
# t: 32000
# ('50', 'v', '140')
# g:  5.0
# v: 140
# f_t18000g40v380
# t18000g40v380
# ('t18000', 'g', '40v380')
# t: 18000
# ('40', 'v', '380')
# g:  4.0
# v: 380
# f_t24000g40v370
# t24000g40v370
# ('t24000', 'g', '40v370')
# t: 24000
# ('40', 'v', '370')
# g:  4.0
# v: 370
# f_t31000g40v390
# t31000g40v390
# ('t31000', 'g', '40v390')
# t: 31000
# ('40', 'v', '390')
# g:  4.0
# v: 390
# f_t27000g30v310
# t27000g30v310
# ('t27000', 'g', '30v310')
# t: 27000
# ('30', 'v', '310')
# g:  3.0
# v: 310
# f_t31000g20v120
# t31000g20v120
# ('t31000', 'g', '20v120')
# t: 31000
# ('20', 'v', '120')
# g:  2.0
# v: 120
# f_t18000g20v130
# t18000g20v130
# ('t18000', 'g', '20v130')
# t: 18000
# ('20', 'v', '130')
# g:  2.0
# v: 130
# f_t21000g45v170
# t21000g45v170
# ('t21000', 'g', '45v170')
# t: 21000
# ('45', 'v', '170')
# g:  4.5
# v: 170
# f_t34000g45v190
# t34000g45v190
# ('t34000', 'g', '45v190')
# t: 34000
# ('45', 'v', '190')
# g:  4.5
# v: 190
# f_t18000g30v130
# t18000g30v130
# ('t18000', 'g', '30v130')
# t: 18000
# ('30', 'v', '130')
# g:  3.0
# v: 130
# f_t31000g30v120
# t31000g30v120
# ('t31000', 'g', '30v120')
# t: 31000
# ('30', 'v', '120')
# g:  3.0
# v: 120
# f_t27000g20v310
# t27000g20v310
# ('t27000', 'g', '20v310')
# t: 27000
# ('20', 'v', '310')
# g:  2.0
# v: 310
# f_t16000g45v260
# t16000g45v260
# ('t16000', 'g', '45v260')
# t: 16000
# ('45', 'v', '260')
# g:  4.5
# v: 260
# f_t37000g45v340
# t37000g45v340
# ('t37000', 'g', '45v340')
# t: 37000
# ('45', 'v', '340')
# g:  4.5
# v: 340
# f_t33000g25v250
# t33000g25v250
# ('t33000', 'g', '25v250')
# t: 33000
# ('25', 'v', '250')
# g:  2.5
# v: 250
# f_t23000g40v200
# t23000g40v200
# ('t23000', 'g', '40v200')
# t: 23000
# ('40', 'v', '200')
# g:  4.0
# v: 200
# f_t33000g35v250
# t33000g35v250
# ('t33000', 'g', '35v250')
# t: 33000
# ('35', 'v', '250')
# g:  3.5
# v: 250
# f_t23000g50v200
# t23000g50v200
# ('t23000', 'g', '50v200')
# t: 23000
# ('50', 'v', '200')
# g:  5.0
# v: 200
# f_t39000g25v380
# t39000g25v380
# ('t39000', 'g', '25v380')
# t: 39000
# ('25', 'v', '380')
# g:  2.5
# v: 380
# f_t24000g25v250
# t24000g25v250
# ('t24000', 'g', '25v250')
# t: 24000
# ('25', 'v', '250')
# g:  2.5
# v: 250
# f_t15000g40v320
# t15000g40v320
# ('t15000', 'g', '40v320')
# t: 15000
# ('40', 'v', '320')
# g:  4.0
# v: 320
# f_t34000g40v200
# t34000g40v200
# ('t34000', 'g', '40v200')
# t: 34000
# ('40', 'v', '200')
# g:  4.0
# v: 200
# f_t17000g20v400
# t17000g20v400
# ('t17000', 'g', '20v400')
# t: 17000
# ('20', 'v', '400')
# g:  2.0
# v: 400
# f_t39000g35v380
# t39000g35v380
# ('t39000', 'g', '35v380')
# t: 39000
# ('35', 'v', '380')
# g:  3.5
# v: 380
# f_t24000g35v250
# t24000g35v250
# ('t24000', 'g', '35v250')
# t: 24000
# ('35', 'v', '250')
# g:  3.5
# v: 250
# f_t15000g50v320
# t15000g50v320
# ('t15000', 'g', '50v320')
# t: 15000
# ('50', 'v', '320')
# g:  5.0
# v: 320
# f_t34000g50v200
# t34000g50v200
# ('t34000', 'g', '50v200')
# t: 34000
# ('50', 'v', '200')
# g:  5.0
# v: 200
# f_t17000g30v400
# t17000g30v400
# ('t17000', 'g', '30v400')
# t: 17000
# ('30', 'v', '400')
# g:  3.0
# v: 400
# f_t26000g20v120
# t26000g20v120
# ('t26000', 'g', '20v120')
# t: 26000
# ('20', 'v', '120')
# g:  2.0
# v: 120
# f_t38000g30v220
# t38000g30v220
# ('t38000', 'g', '30v220')
# t: 38000
# ('30', 'v', '220')
# g:  3.0
# v: 220
# f_t30000g30v310
# t30000g30v310
# ('t30000', 'g', '30v310')
# t: 30000
# ('30', 'v', '310')
# g:  3.0
# v: 310
# f_t19000g30v300
# t19000g30v300
# ('t19000', 'g', '30v300')
# t: 19000
# ('30', 'v', '300')
# g:  3.0
# v: 300
# f_t36000g45v170
# t36000g45v170
# ('t36000', 'g', '45v170')
# t: 36000
# ('45', 'v', '170')
# g:  4.5
# v: 170
# f_t23000g45v190
# t23000g45v190
# ('t23000', 'g', '45v190')
# t: 23000
# ('45', 'v', '190')
# g:  4.5
# v: 190
# f_t38000g20v220
# t38000g20v220
# ('t38000', 'g', '20v220')
# t: 38000
# ('20', 'v', '220')
# g:  2.0
# v: 220
# f_t19000g20v300
# t19000g20v300
# ('t19000', 'g', '20v300')
# t: 19000
# ('20', 'v', '300')
# g:  2.0
# v: 300
# f_t30000g20v310
# t30000g20v310
# ('t30000', 'g', '20v310')
# t: 30000
# ('20', 'v', '310')
# g:  2.0
# v: 310
# f_t26000g30v120
# t26000g30v120
# ('t26000', 'g', '30v120')
# t: 26000
# ('30', 'v', '120')
# g:  3.0
# v: 120
# f_t28000g45v270
# t28000g45v270
# ('t28000', 'g', '45v270')
# t: 28000
# ('45', 'v', '270')
# g:  4.5
# v: 270
# f_t20000g45v340
# t20000g45v340
# ('t20000', 'g', '45v340')
# t: 20000
# ('45', 'v', '340')
# g:  4.5
# v: 340
# f_t23000g35v320
# t23000g35v320
# ('t23000', 'g', '35v320')
# t: 23000
# ('35', 'v', '320')
# g:  3.5
# v: 320
# f_t35000g25v110
# t35000g25v110
# ('t35000', 'g', '25v110')
# t: 35000
# ('25', 'v', '110')
# g:  2.5
# v: 110
# f_t25000g40v140
# t25000g40v140
# ('t25000', 'g', '40v140')
# t: 25000
# ('40', 'v', '140')
# g:  4.0
# v: 140
# f_t26000g50v390
# t26000g50v390
# ('t26000', 'g', '50v390')
# t: 26000
# ('50', 'v', '390')
# g:  5.0
# v: 390
# f_t33000g50v370
# t33000g50v370
# ('t33000', 'g', '50v370')
# t: 33000
# ('50', 'v', '370')
# g:  5.0
# v: 370
# f_t35000g35v110
# t35000g35v110
# ('t35000', 'g', '35v110')
# t: 35000
# ('35', 'v', '110')
# g:  3.5
# v: 110
# f_t23000g25v320
# t23000g25v320
# ('t23000', 'g', '25v320')
# t: 23000
# ('25', 'v', '320')
# g:  2.5
# v: 320
# f_t21000g45v400
# t21000g45v400
# ('t21000', 'g', '45v400')
# t: 21000
# ('45', 'v', '400')
# g:  4.5
# v: 400
# f_t33000g40v370
# t33000g40v370
# ('t33000', 'g', '40v370')
# t: 33000
# ('40', 'v', '370')
# g:  4.0
# v: 370
# f_t26000g40v390
# t26000g40v390
# ('t26000', 'g', '40v390')
# t: 26000
# ('40', 'v', '390')
# g:  4.0
# v: 390
# f_t25000g50v140
# t25000g50v140
# ('t25000', 'g', '50v140')
# t: 25000
# ('50', 'v', '140')
# g:  5.0
# v: 140
# f_t15000g30v190
# t15000g30v190
# ('t15000', 'g', '30v190')
# t: 15000
# ('30', 'v', '190')
# g:  3.0
# v: 190
# f_t29000g30v160
# t29000g30v160
# ('t29000', 'g', '30v160')
# t: 29000
# ('30', 'v', '160')
# g:  3.0
# v: 160
# f_t22000g20v280
# t22000g20v280
# ('t22000', 'g', '20v280')
# t: 22000
# ('20', 'v', '280')
# g:  2.0
# v: 280
# f_t37000g20v260
# t37000g20v260
# ('t37000', 'g', '20v260')
# t: 37000
# ('20', 'v', '260')
# g:  2.0
# v: 260
# f_t16000g20v340
# t16000g20v340
# ('t16000', 'g', '20v340')
# t: 16000
# ('20', 'v', '340')
# g:  2.0
# v: 340
# f_t27000g45v230
# t27000g45v230
# ('t27000', 'g', '45v230')
# t: 27000
# ('45', 'v', '230')
# g:  4.5
# v: 230
# f_t37000g30v260
# t37000g30v260
# ('t37000', 'g', '30v260')
# t: 37000
# ('30', 'v', '260')
# g:  3.0
# v: 260
# f_t22000g30v280
# t22000g30v280
# ('t22000', 'g', '30v280')
# t: 22000
# ('30', 'v', '280')
# g:  3.0
# v: 280
# f_t16000g30v340
# t16000g30v340
# ('t16000', 'g', '30v340')
# t: 16000
# ('30', 'v', '340')
# g:  3.0
# v: 340
# f_t15000g20v190
# t15000g20v190
# ('t15000', 'g', '20v190')
# t: 15000
# ('20', 'v', '190')
# g:  2.0
# v: 190
# f_t29000g20v160
# t29000g20v160
# ('t29000', 'g', '20v160')
# t: 29000
# ('20', 'v', '160')
# g:  2.0
# v: 160
# f_t39000g45v130
# t39000g45v130
# ('t39000', 'g', '45v130')
# t: 39000
# ('45', 'v', '130')
# g:  4.5
# v: 130
# f_t22000g40v150
# t22000g40v150
# ('t22000', 'g', '40v150')
# t: 22000
# ('40', 'v', '150')
# g:  4.0
# v: 150
# f_t34000g50v360
# t34000g50v360
# ('t34000', 'g', '50v360')
# t: 34000
# ('50', 'v', '360')
# g:  5.0
# v: 360
# f_t21000g50v380
# t21000g50v380
# ('t21000', 'g', '50v380')
# t: 21000
# ('50', 'v', '380')
# g:  5.0
# v: 380
# f_t15000g50v240
# t15000g50v240
# ('t15000', 'g', '50v240')
# t: 15000
# ('50', 'v', '240')
# g:  5.0
# v: 240
# f_t24000g35v330
# t24000g35v330
# ('t24000', 'g', '35v330')
# t: 24000
# ('35', 'v', '330')
# g:  3.5
# v: 330
# f_t32000g25v100
# t32000g25v100
# ('t32000', 'g', '25v100')
# t: 32000
# ('25', 'v', '100')
# g:  2.5
# v: 100
# f_t21000g40v380
# t21000g40v380
# ('t21000', 'g', '40v380')
# t: 21000
# ('40', 'v', '380')
# g:  4.0
# v: 380
# f_t34000g40v360
# t34000g40v360
# ('t34000', 'g', '40v360')
# t: 34000
# ('40', 'v', '360')
# g:  4.0
# v: 360
# f_t15000g40v240
# t15000g40v240
# ('t15000', 'g', '40v240')
# t: 15000
# ('40', 'v', '240')
# g:  4.0
# v: 240
# f_t22000g50v150
# t22000g50v150
# ('t22000', 'g', '50v150')
# t: 22000
# ('50', 'v', '150')
# g:  5.0
# v: 150
# f_t32000g35v100
# t32000g35v100
# ('t32000', 'g', '35v100')
# t: 32000
# ('35', 'v', '100')
# g:  3.5
# v: 100
# f_t24000g25v330
# t24000g25v330
# ('t24000', 'g', '25v330')
# t: 24000
# ('25', 'v', '330')
# g:  2.5
# v: 330
# f_t20000g45v220
# t20000g45v220
# ('t20000', 'g', '45v220')
# t: 20000
# ('45', 'v', '220')
# g:  4.5
# v: 220
# f_t28000g45v310
# t28000g45v310
# ('t28000', 'g', '45v310')
# t: 28000
# ('45', 'v', '310')
# g:  4.5
# v: 310
# f_t30000g20v270
# t30000g20v270
# ('t30000', 'g', '20v270')
# t: 30000
# ('20', 'v', '270')
# g:  2.0
# v: 270
# f_t19000g20v260
# t19000g20v260
# ('t19000', 'g', '20v260')
# t: 19000
# ('20', 'v', '260')
# g:  2.0
# v: 260
# f_t25000g20v290
# t25000g20v290
# ('t25000', 'g', '20v290')
# t: 25000
# ('20', 'v', '290')
# g:  2.0
# v: 290
# f_t38000g20v340
# t38000g20v340
# ('t38000', 'g', '20v340')
# t: 38000
# ('20', 'v', '340')
# g:  2.0
# v: 340
# f_t17000g45v130
# t17000g45v130
# ('t17000', 'g', '45v130')
# t: 17000
# ('45', 'v', '130')
# g:  4.5
# v: 130
# f_t19000g30v260
# t19000g30v260
# ('t19000', 'g', '30v260')
# t: 19000
# ('30', 'v', '260')
# g:  3.0
# v: 260
# f_t25000g30v290
# t25000g30v290
# ('t25000', 'g', '30v290')
# t: 25000
# ('30', 'v', '290')
# g:  3.0
# v: 290
# f_t30000g30v270
# t30000g30v270
# ('t30000', 'g', '30v270')
# t: 30000
# ('30', 'v', '270')
# g:  3.0
# v: 270
# f_t38000g30v340
# t38000g30v340
# ('t38000', 'g', '30v340')
# t: 38000
# ('30', 'v', '340')
# g:  3.0
# v: 340
# f_t39000g20v400
# t39000g20v400
# ('t39000', 'g', '20v400')
# t: 39000
# ('20', 'v', '400')
# g:  2.0
# v: 400
# f_t33000g40v210
# t33000g40v210
# ('t33000', 'g', '40v210')
# t: 33000
# ('40', 'v', '210')
# g:  4.0
# v: 210
# f_t17000g25v380
# t17000g25v380
# ('t17000', 'g', '25v380')
# t: 17000
# ('25', 'v', '380')
# g:  2.5
# v: 380
# f_t23000g25v240
# t23000g25v240
# ('t23000', 'g', '25v240')
# t: 23000
# ('25', 'v', '240')
# g:  2.5
# v: 240
# f_t33000g50v210
# t33000g50v210
# ('t33000', 'g', '50v210')
# t: 33000
# ('50', 'v', '210')
# g:  5.0
# v: 210
# f_t39000g30v400
# t39000g30v400
# ('t39000', 'g', '30v400')
# t: 39000
# ('30', 'v', '400')
# g:  3.0
# v: 400
# f_t17000g35v380
# t17000g35v380
# ('t17000', 'g', '35v380')
# t: 17000
# ('35', 'v', '380')
# g:  3.5
# v: 380
# f_t23000g35v240
# t23000g35v240
# ('t23000', 'g', '35v240')
# t: 23000
# ('35', 'v', '240')
# g:  3.5
# v: 240
# f_t18000g45v170
# t18000g45v170
# ('t18000', 'g', '45v170')
# t: 18000
# ('45', 'v', '170')
# g:  4.5
# v: 170
# f_t24000g45v180
# t24000g45v180
# ('t24000', 'g', '45v180')
# t: 24000
# ('45', 'v', '180')
# g:  4.5
# v: 180
# f_t31000g45v160
# t31000g45v160
# ('t31000', 'g', '45v160')
# t: 31000
# ('45', 'v', '160')
# g:  4.5
# v: 160
# f_t21000g20v130
# t21000g20v130
# ('t21000', 'g', '20v130')
# t: 21000
# ('20', 'v', '130')
# g:  2.0
# v: 130
# f_t16000g30v220
# t16000g30v220
# ('t16000', 'g', '30v220')
# t: 16000
# ('30', 'v', '220')
# g:  3.0
# v: 220
# f_t37000g30v300
# t37000g30v300
# ('t37000', 'g', '30v300')
# t: 37000
# ('30', 'v', '300')
# g:  3.0
# v: 300
# f_t27000g45v350
# t27000g45v350
# ('t27000', 'g', '45v350')
# t: 27000
# ('45', 'v', '350')
# g:  4.5
# v: 350
# f_t16000g20v220
# t16000g20v220
# ('t16000', 'g', '20v220')
# t: 16000
# ('20', 'v', '220')
# g:  2.0
# v: 220
# f_t37000g20v300
# t37000g20v300
# ('t37000', 'g', '20v300')
# t: 37000
# ('20', 'v', '300')
# g:  2.0
# v: 300
# f_t21000g30v130
# t21000g30v130
# ('t21000', 'g', '30v130')
# t: 21000
# ('30', 'v', '130')
# g:  3.0
# v: 130
# f_t33000g45v180
# t33000g45v180
# ('t33000', 'g', '45v180')
# t: 33000
# ('45', 'v', '180')
# g:  4.5
# v: 180
# f_t26000g45v160
# t26000g45v160
# ('t26000', 'g', '45v160')
# t: 26000
# ('45', 'v', '160')
# g:  4.5
# v: 160
# f_t28000g30v230
# t28000g30v230
# ('t28000', 'g', '30v230')
# t: 28000
# ('30', 'v', '230')
# g:  3.0
# v: 230
# f_t20000g30v300
# t20000g30v300
# ('t20000', 'g', '30v300')
# t: 20000
# ('30', 'v', '300')
# g:  3.0
# v: 300
# f_t36000g20v130
# t36000g20v130
# ('t36000', 'g', '20v130')
# t: 36000
# ('20', 'v', '130')
# g:  2.0
# v: 130
# f_t38000g45v260
# t38000g45v260
# ('t38000', 'g', '45v260')
# t: 38000
# ('45', 'v', '260')
# g:  4.5
# v: 260
# f_t30000g45v350
# t30000g45v350
# ('t30000', 'g', '45v350')
# t: 30000
# ('45', 'v', '350')
# g:  4.5
# v: 350
# f_t19000g45v340
# t19000g45v340
# ('t19000', 'g', '45v340')
# t: 19000
# ('45', 'v', '340')
# g:  4.5
# v: 340
# f_t36000g30v130
# t36000g30v130
# ('t36000', 'g', '30v130')
# t: 36000
# ('30', 'v', '130')
# g:  3.0
# v: 130
# f_t28000g20v230
# t28000g20v230
# ('t28000', 'g', '20v230')
# t: 28000
# ('20', 'v', '230')
# g:  2.0
# v: 230
# f_t20000g20v300
# t20000g20v300
# ('t20000', 'g', '20v300')
# t: 20000
# ('20', 'v', '300')
# g:  2.0
# v: 300
# f_t24000g40v210
# t24000g40v210
# ('t24000', 'g', '40v210')
# t: 24000
# ('40', 'v', '210')
# g:  4.0
# v: 210
# f_t15000g25v360
# t15000g25v360
# ('t15000', 'g', '25v360')
# t: 15000
# ('25', 'v', '360')
# g:  2.5
# v: 360
# f_t29000g25v390
# t29000g25v390
# ('t29000', 'g', '25v390')
# t: 29000
# ('25', 'v', '390')
# g:  2.5
# v: 390
# f_t34000g25v240
# t34000g25v240
# ('t34000', 'g', '25v240')
# t: 34000
# ('25', 'v', '240')
# g:  2.5
# v: 240
# f_t24000g50v210
# t24000g50v210
# ('t24000', 'g', '50v210')
# t: 24000
# ('50', 'v', '210')
# g:  5.0
# v: 210
# f_t15000g35v360
# t15000g35v360
# ('t15000', 'g', '35v360')
# t: 15000
# ('35', 'v', '360')
# g:  3.5
# v: 360
# f_t29000g35v390
# t29000g35v390
# ('t29000', 'g', '35v390')
# t: 29000
# ('35', 'v', '390')
# g:  3.5
# v: 390
# f_t34000g35v240
# t34000g35v240
# ('t34000', 'g', '35v240')
# t: 34000
# ('35', 'v', '240')
# g:  3.5
# v: 240
# f_t37000g45v220
# t37000g45v220
# ('t37000', 'g', '45v220')
# t: 37000
# ('45', 'v', '220')
# g:  4.5
# v: 220
# f_t16000g45v300
# t16000g45v300
# ('t16000', 'g', '45v300')
# t: 16000
# ('45', 'v', '300')
# g:  4.5
# v: 300
# f_t27000g20v270
# t27000g20v270
# ('t27000', 'g', '20v270')
# t: 27000
# ('20', 'v', '270')
# g:  2.0
# v: 270
# f_t32000g20v290
# t32000g20v290
# ('t32000', 'g', '20v290')
# t: 32000
# ('20', 'v', '290')
# g:  2.0
# v: 290
# f_t39000g30v170
# t39000g30v170
# ('t39000', 'g', '30v170')
# t: 39000
# ('30', 'v', '170')
# g:  3.0
# v: 170
# f_t29000g45v120
# t29000g45v120
# ('t29000', 'g', '45v120')
# t: 29000
# ('45', 'v', '120')
# g:  4.5
# v: 120
# f_t39000g20v170
# t39000g20v170
# ('t39000', 'g', '20v170')
# t: 39000
# ('20', 'v', '170')
# g:  2.0
# v: 170
# f_t32000g30v290
# t32000g30v290
# ('t32000', 'g', '30v290')
# t: 32000
# ('30', 'v', '290')
# g:  3.0
# v: 290
# f_t27000g30v270
# t27000g30v270
# ('t27000', 'g', '30v270')
# t: 27000
# ('30', 'v', '270')
# g:  3.0
# v: 270
# f_t23000g50v360
# t23000g50v360
# ('t23000', 'g', '50v360')
# t: 23000
# ('50', 'v', '360')
# g:  5.0
# v: 360
# f_t36000g50v380
# t36000g50v380
# ('t36000', 'g', '50v380')
# t: 36000
# ('50', 'v', '380')
# g:  5.0
# v: 380
# f_t35000g40v150
# t35000g40v150
# ('t35000', 'g', '40v150')
# t: 35000
# ('40', 'v', '150')
# g:  4.0
# v: 150
# f_t25000g25v100
# t25000g25v100
# ('t25000', 'g', '25v100')
# t: 25000
# ('25', 'v', '100')
# g:  2.5
# v: 100
# f_t33000g35v330
# t33000g35v330
# ('t33000', 'g', '35v330')
# t: 33000
# ('35', 'v', '330')
# g:  3.5
# v: 330
# f_t35000g50v150
# t35000g50v150
# ('t35000', 'g', '50v150')
# t: 35000
# ('50', 'v', '150')
# g:  5.0
# v: 150
# f_t36000g40v380
# t36000g40v380
# ('t36000', 'g', '40v380')
# t: 36000
# ('40', 'v', '380')
# g:  4.0
# v: 380
# f_t23000g40v360
# t23000g40v360
# ('t23000', 'g', '40v360')
# t: 23000
# ('40', 'v', '360')
# g:  4.0
# v: 360
# f_t33000g25v330
# t33000g25v330
# ('t33000', 'g', '25v330')
# t: 33000
# ('25', 'v', '330')
# g:  2.5
# v: 330
# f_t18000g45v400
# t18000g45v400
# ('t18000', 'g', '45v400')
# t: 18000
# ('45', 'v', '400')
# g:  4.5
# v: 400
# f_t25000g35v100
# t25000g35v100
# ('t25000', 'g', '35v100')
# t: 25000
# ('35', 'v', '100')
# g:  3.5
# v: 100
# f_t33000g20v260
# t33000g20v260
# ('t33000', 'g', '20v260')
# t: 33000
# ('20', 'v', '260')
# g:  2.0
# v: 260
# f_t26000g20v280
# t26000g20v280
# ('t26000', 'g', '20v280')
# t: 26000
# ('20', 'v', '280')
# g:  2.0
# v: 280
# f_t38000g30v180
# t38000g30v180
# ('t38000', 'g', '30v180')
# t: 38000
# ('30', 'v', '180')
# g:  3.0
# v: 180
# f_t23000g45v230
# t23000g45v230
# ('t23000', 'g', '45v230')
# t: 23000
# ('45', 'v', '230')
# g:  4.5
# v: 230
# f_t38000g20v180
# t38000g20v180
# ('t38000', 'g', '20v180')
# t: 38000
# ('20', 'v', '180')
# g:  2.0
# v: 180
# f_t26000g30v280
# t26000g30v280
# ('t26000', 'g', '30v280')
# t: 26000
# ('30', 'v', '280')
# g:  3.0
# v: 280
# f_t33000g30v260
# t33000g30v260
# ('t33000', 'g', '30v260')
# t: 33000
# ('30', 'v', '260')
# g:  3.0
# v: 260
# f_t31000g25v110
# t31000g25v110
# ('t31000', 'g', '25v110')
# t: 31000
# ('25', 'v', '110')
# g:  2.5
# v: 110
# f_t18000g25v100
# t18000g25v100
# ('t18000', 'g', '25v100')
# t: 18000
# ('25', 'v', '100')
# g:  2.5
# v: 100
# f_t27000g35v320
# t27000g35v320
# ('t27000', 'g', '35v320')
# t: 27000
# ('35', 'v', '320')
# g:  3.5
# v: 320
# f_t16000g50v250
# t16000g50v250
# ('t16000', 'g', '50v250')
# t: 16000
# ('50', 'v', '250')
# g:  5.0
# v: 250
# f_t37000g50v370
# t37000g50v370
# ('t37000', 'g', '50v370')
# t: 37000
# ('50', 'v', '370')
# g:  5.0
# v: 370
# f_t22000g50v390
# t22000g50v390
# ('t22000', 'g', '50v390')
# t: 22000
# ('50', 'v', '390')
# g:  5.0
# v: 390
# f_t21000g40v140
# t21000g40v140
# ('t21000', 'g', '40v140')
# t: 21000
# ('40', 'v', '140')
# g:  4.0
# v: 140
# f_t25000g45v400
# t25000g45v400
# ('t25000', 'g', '45v400')
# t: 25000
# ('45', 'v', '400')
# g:  4.5
# v: 400
# f_t27000g25v320
# t27000g25v320
# ('t27000', 'g', '25v320')
# t: 27000
# ('25', 'v', '320')
# g:  2.5
# v: 320
# f_t18000g35v100
# t18000g35v100
# ('t18000', 'g', '35v100')
# t: 18000
# ('35', 'v', '100')
# g:  3.5
# v: 100
# f_t31000g35v110
# t31000g35v110
# ('t31000', 'g', '35v110')
# t: 31000
# ('35', 'v', '110')
# g:  3.5
# v: 110
# f_t21000g50v140
# t21000g50v140
# ('t21000', 'g', '50v140')
# t: 21000
# ('50', 'v', '140')
# g:  5.0
# v: 140
# f_t16000g40v250
# t16000g40v250
# ('t16000', 'g', '40v250')
# t: 16000
# ('40', 'v', '250')
# g:  4.0
# v: 250
# f_t22000g40v390
# t22000g40v390
# ('t22000', 'g', '40v390')
# t: 22000
# ('40', 'v', '390')
# g:  4.0
# v: 390
# f_t37000g40v370
# t37000g40v370
# ('t37000', 'g', '40v370')
# t: 37000
# ('40', 'v', '370')
# g:  4.0
# v: 370
# f_t34000g30v310
# t34000g30v310
# ('t34000', 'g', '30v310')
# t: 34000
# ('30', 'v', '310')
# g:  3.0
# v: 310
# f_t15000g30v230
# t15000g30v230
# ('t15000', 'g', '30v230')
# t: 15000
# ('30', 'v', '230')
# g:  3.0
# v: 230
# f_t22000g20v120
# t22000g20v120
# ('t22000', 'g', '20v120')
# t: 22000
# ('20', 'v', '120')
# g:  2.0
# v: 120
# f_t27000g45v190
# t27000g45v190
# ('t27000', 'g', '45v190')
# t: 27000
# ('45', 'v', '190')
# g:  4.5
# v: 190
# f_t32000g45v170
# t32000g45v170
# ('t32000', 'g', '45v170')
# t: 32000
# ('45', 'v', '170')
# g:  4.5
# v: 170
# f_t22000g30v120
# t22000g30v120
# ('t22000', 'g', '30v120')
# t: 22000
# ('30', 'v', '120')
# g:  3.0
# v: 120
# f_t34000g20v310
# t34000g20v310
# ('t34000', 'g', '20v310')
# t: 34000
# ('20', 'v', '310')
# g:  2.0
# v: 310
# f_t15000g20v230
# t15000g20v230
# ('t15000', 'g', '20v230')
# t: 15000
# ('20', 'v', '230')
# g:  2.0
# v: 230
# f_t24000g45v340
# t24000g45v340
# ('t24000', 'g', '45v340')
# t: 24000
# ('45', 'v', '340')
# g:  4.5
# v: 340
# f_t39000g45v290
# t39000g45v290
# ('t39000', 'g', '45v290')
# t: 39000
# ('45', 'v', '290')
# g:  4.5
# v: 290
# f_t17000g35v140
# t17000g35v140
# ('t17000', 'g', '35v140')
# t: 17000
# ('35', 'v', '140')
# g:  3.5
# v: 140
# f_t20000g25v250
# t20000g25v250
# ('t20000', 'g', '25v250')
# t: 20000
# ('25', 'v', '250')
# g:  2.5
# v: 250
# f_t28000g25v360
# t28000g25v360
# ('t28000', 'g', '25v360')
# t: 28000
# ('25', 'v', '360')
# g:  2.5
# v: 360
# f_t19000g40v210
# t19000g40v210
# ('t19000', 'g', '40v210')
# t: 19000
# ('40', 'v', '210')
# g:  4.0
# v: 210
# f_t30000g40v200
# t30000g40v200
# ('t30000', 'g', '40v200')
# t: 30000
# ('40', 'v', '200')
# g:  4.0
# v: 200
# f_t38000g40v330
# t38000g40v330
# ('t38000', 'g', '40v330')
# t: 38000
# ('40', 'v', '330')
# g:  4.0
# v: 330
# f_t20000g35v250
# t20000g35v250
# ('t20000', 'g', '35v250')
# t: 20000
# ('35', 'v', '250')
# g:  3.5
# v: 250
# f_t28000g35v360
# t28000g35v360
# ('t28000', 'g', '35v360')
# t: 28000
# ('35', 'v', '360')
# g:  3.5
# v: 360
# f_t17000g25v140
# t17000g25v140
# ('t17000', 'g', '25v140')
# t: 17000
# ('25', 'v', '140')
# g:  2.5
# v: 140
# f_t30000g50v200
# t30000g50v200
# ('t30000', 'g', '50v200')
# t: 30000
# ('50', 'v', '200')
# g:  5.0
# v: 200
# f_t19000g50v210
# t19000g50v210
# ('t19000', 'g', '50v210')
# t: 19000
# ('50', 'v', '210')
# g:  5.0
# v: 210
# f_t38000g50v330
# t38000g50v330
# ('t38000', 'g', '50v330')
# t: 38000
# ('50', 'v', '330')
# g:  5.0
# v: 330
# f_t37000g25v250
# t37000g25v250
# ('t37000', 'g', '25v250')
# t: 37000
# ('25', 'v', '250')
# g:  2.5
# v: 250
# f_t16000g25v370
# t16000g25v370
# ('t16000', 'g', '25v370')
# t: 16000
# ('25', 'v', '370')
# g:  2.5
# v: 370
# f_t29000g35v150
# t29000g35v150
# ('t29000', 'g', '35v150')
# t: 29000
# ('35', 'v', '150')
# g:  3.5
# v: 150
# f_t39000g50v100
# t39000g50v100
# ('t39000', 'g', '50v100')
# t: 39000
# ('50', 'v', '100')
# g:  5.0
# v: 100
# f_t27000g40v200
# t27000g40v200
# ('t27000', 'g', '40v200')
# t: 27000
# ('40', 'v', '200')
# g:  4.0
# v: 200
# f_t29000g25v150
# t29000g25v150
# ('t29000', 'g', '25v150')
# t: 29000
# ('25', 'v', '150')
# g:  2.5
# v: 150
# f_t37000g35v250
# t37000g35v250
# ('t37000', 'g', '35v250')
# t: 37000
# ('35', 'v', '250')
# g:  3.5
# v: 250
# f_t16000g35v370
# t16000g35v370
# ('t16000', 'g', '35v370')
# t: 16000
# ('35', 'v', '370')
# g:  3.5
# v: 370
# f_t27000g50v200
# t27000g50v200
# ('t27000', 'g', '50v200')
# t: 27000
# ('50', 'v', '200')
# g:  5.0
# v: 200
# f_t39000g40v100
# t39000g40v100
# ('t39000', 'g', '40v100')
# t: 39000
# ('40', 'v', '100')
# g:  4.0
# v: 100
# f_t35000g20v120
# t35000g20v120
# ('t35000', 'g', '20v120')
# t: 35000
# ('20', 'v', '120')
# g:  2.0
# v: 120
# f_t23000g30v310
# t23000g30v310
# ('t23000', 'g', '30v310')
# t: 23000
# ('30', 'v', '310')
# g:  3.0
# v: 310
# f_t30000g45v190
# t30000g45v190
# ('t30000', 'g', '45v190')
# t: 30000
# ('45', 'v', '190')
# g:  4.5
# v: 190
# f_t25000g45v170
# t25000g45v170
# ('t25000', 'g', '45v170')
# t: 25000
# ('45', 'v', '170')
# g:  4.5
# v: 170
# f_t19000g45v180
# t19000g45v180
# ('t19000', 'g', '45v180')
# t: 19000
# ('45', 'v', '180')
# g:  4.5
# v: 180
# f_t23000g20v310
# t23000g20v310
# ('t23000', 'g', '20v310')
# t: 23000
# ('20', 'v', '310')
# g:  2.0
# v: 310
# f_t35000g30v120
# t35000g30v120
# ('t35000', 'g', '30v120')
# t: 35000
# ('30', 'v', '120')
# g:  3.0
# v: 120
# f_t33000g45v340
# t33000g45v340
# ('t33000', 'g', '45v340')
# t: 33000
# ('45', 'v', '340')
# g:  4.5
# v: 340
# f_t38000g35v210
# t38000g35v210
# ('t38000', 'g', '35v210')
# t: 38000
# ('35', 'v', '210')
# g:  3.5
# v: 210
# f_t30000g35v320
# t30000g35v320
# ('t30000', 'g', '35v320')
# t: 30000
# ('35', 'v', '320')
# g:  3.5
# v: 320
# f_t19000g35v330
# t19000g35v330
# ('t19000', 'g', '35v330')
# t: 19000
# ('35', 'v', '330')
# g:  3.5
# v: 330
# f_t26000g25v110
# t26000g25v110
# ('t26000', 'g', '25v110')
# t: 26000
# ('25', 'v', '110')
# g:  2.5
# v: 110
# f_t36000g40v140
# t36000g40v140
# ('t36000', 'g', '40v140')
# t: 36000
# ('40', 'v', '140')
# g:  4.0
# v: 140
# f_t28000g50v240
# t28000g50v240
# ('t28000', 'g', '50v240')
# t: 28000
# ('50', 'v', '240')
# g:  5.0
# v: 240
# f_t20000g50v370
# t20000g50v370
# ('t20000', 'g', '50v370')
# t: 20000
# ('50', 'v', '370')
# g:  5.0
# v: 370
# f_t35000g50v390
# t35000g50v390
# ('t35000', 'g', '50v390')
# t: 35000
# ('50', 'v', '390')
# g:  5.0
# v: 390
# f_t26000g35v110
# t26000g35v110
# ('t26000', 'g', '35v110')
# t: 26000
# ('35', 'v', '110')
# g:  3.5
# v: 110
# f_t38000g25v210
# t38000g25v210
# ('t38000', 'g', '25v210')
# t: 38000
# ('25', 'v', '210')
# g:  2.5
# v: 210
# f_t32000g45v400
# t32000g45v400
# ('t32000', 'g', '45v400')
# t: 32000
# ('45', 'v', '400')
# g:  4.5
# v: 400
# f_t19000g25v330
# t19000g25v330
# ('t19000', 'g', '25v330')
# t: 19000
# ('25', 'v', '330')
# g:  2.5
# v: 330
# f_t30000g25v320
# t30000g25v320
# ('t30000', 'g', '25v320')
# t: 30000
# ('25', 'v', '320')
# g:  2.5
# v: 320
# f_t28000g40v240
# t28000g40v240
# ('t28000', 'g', '40v240')
# t: 28000
# ('40', 'v', '240')
# g:  4.0
# v: 240
# f_t35000g40v390
# t35000g40v390
# ('t35000', 'g', '40v390')
# t: 35000
# ('40', 'v', '390')
# g:  4.0
# v: 390
# f_t20000g40v370
# t20000g40v370
# ('t20000', 'g', '40v370')
# t: 20000
# ('40', 'v', '370')
# g:  4.0
# v: 370
# f_t36000g50v140
# t36000g50v140
# ('t36000', 'g', '50v140')
# t: 36000
# ('50', 'v', '140')
# g:  5.0
# v: 140
# f_t24000g20v260
# t24000g20v260
# ('t24000', 'g', '20v260')
# t: 24000
# ('20', 'v', '260')
# g:  2.0
# v: 260
# f_t18000g20v290
# t18000g20v290
# ('t18000', 'g', '20v290')
# t: 18000
# ('20', 'v', '290')
# g:  2.0
# v: 290
# f_t31000g20v280
# t31000g20v280
# ('t31000', 'g', '20v280')
# t: 31000
# ('20', 'v', '280')
# g:  2.0
# v: 280
# f_t15000g45v310
# t15000g45v310
# ('t15000', 'g', '45v310')
# t: 15000
# ('45', 'v', '310')
# g:  4.5
# v: 310
# f_t34000g45v230
# t34000g45v230
# ('t34000', 'g', '45v230')
# t: 34000
# ('45', 'v', '230')
# g:  4.5
# v: 230
# f_t31000g30v280
# t31000g30v280
# ('t31000', 'g', '30v280')
# t: 31000
# ('30', 'v', '280')
# g:  3.0
# v: 280
# f_t24000g30v260
# t24000g30v260
# ('t24000', 'g', '30v260')
# t: 24000
# ('30', 'v', '260')
# g:  3.0
# v: 260
# f_t18000g30v290
# t18000g30v290
# ('t18000', 'g', '30v290')
# t: 18000
# ('30', 'v', '290')
# g:  3.0
# v: 290
# f_t18000g40v140
# t18000g40v140
# ('t18000', 'g', '40v140')
# t: 18000
# ('40', 'v', '140')
# g:  4.0
# v: 140
# f_t31000g40v150
# t31000g40v150
# ('t31000', 'g', '40v150')
# t: 31000
# ('40', 'v', '150')
# g:  4.0
# v: 150
# f_t32000g50v380
# t32000g50v380
# ('t32000', 'g', '50v380')
# t: 32000
# ('50', 'v', '380')
# g:  5.0
# v: 380
# f_t27000g50v360
# t27000g50v360
# ('t27000', 'g', '50v360')
# t: 27000
# ('50', 'v', '360')
# g:  5.0
# v: 360
# f_t16000g35v210
# t16000g35v210
# ('t16000', 'g', '35v210')
# t: 16000
# ('35', 'v', '210')
# g:  3.5
# v: 210
# f_t37000g35v330
# t37000g35v330
# ('t37000', 'g', '35v330')
# t: 37000
# ('35', 'v', '330')
# g:  3.5
# v: 330
# f_t21000g25v100
# t21000g25v100
# ('t21000', 'g', '25v100')
# t: 21000
# ('25', 'v', '100')
# g:  2.5
# v: 100
# f_t27000g40v360
# t27000g40v360
# ('t27000', 'g', '40v360')
# t: 27000
# ('40', 'v', '360')
# g:  4.0
# v: 360
# f_t32000g40v380
# t32000g40v380
# ('t32000', 'g', '40v380')
# t: 32000
# ('40', 'v', '380')
# g:  4.0
# v: 380
# f_t31000g50v150
# t31000g50v150
# ('t31000', 'g', '50v150')
# t: 31000
# ('50', 'v', '150')
# g:  5.0
# v: 150
# f_t18000g50v140
# t18000g50v140
# ('t18000', 'g', '50v140')
# t: 18000
# ('50', 'v', '140')
# g:  5.0
# v: 140
# f_t21000g35v100
# t21000g35v100
# ('t21000', 'g', '35v100')
# t: 21000
# ('35', 'v', '100')
# g:  3.5
# v: 100
# f_t16000g25v210
# t16000g25v210
# ('t16000', 'g', '25v210')
# t: 16000
# ('25', 'v', '210')
# g:  2.5
# v: 210
# f_t37000g25v330
# t37000g25v330
# ('t37000', 'g', '25v330')
# t: 37000
# ('25', 'v', '330')
# g:  2.5
# v: 330
# f_t33000g45v220
# t33000g45v220
# ('t33000', 'g', '45v220')
# t: 33000
# ('45', 'v', '220')
# g:  4.5
# v: 220
# f_t28000g30v190
# t28000g30v190
# ('t28000', 'g', '30v190')
# t: 28000
# ('30', 'v', '190')
# g:  3.0
# v: 190
# f_t36000g20v290
# t36000g20v290
# ('t36000', 'g', '20v290')
# t: 36000
# ('20', 'v', '290')
# g:  2.0
# v: 290
# f_t23000g20v270
# t23000g20v270
# ('t23000', 'g', '20v270')
# t: 23000
# ('20', 'v', '270')
# g:  2.0
# v: 270
# f_t23000g30v270
# t23000g30v270
# ('t23000', 'g', '30v270')
# t: 23000
# ('30', 'v', '270')
# g:  3.0
# v: 270
# f_t36000g30v290
# t36000g30v290
# ('t36000', 'g', '30v290')
# t: 36000
# ('30', 'v', '290')
# g:  3.0
# v: 290
# f_t28000g20v190
# t28000g20v190
# ('t28000', 'g', '20v190')
# t: 28000
# ('20', 'v', '190')
# g:  2.0
# v: 190
# f_t17000g50v100
# t17000g50v100
# ('t17000', 'g', '50v100')
# t: 17000
# ('50', 'v', '100')
# g:  5.0
# v: 100
# f_t20000g40v210
# t20000g40v210
# ('t20000', 'g', '40v210')
# t: 20000
# ('40', 'v', '210')
# g:  4.0
# v: 210
# f_t28000g40v320
# t28000g40v320
# ('t28000', 'g', '40v320')
# t: 28000
# ('40', 'v', '320')
# g:  4.0
# v: 320
# f_t30000g25v240
# t30000g25v240
# ('t30000', 'g', '25v240')
# t: 30000
# ('25', 'v', '240')
# g:  2.5
# v: 240
# f_t19000g25v250
# t19000g25v250
# ('t19000', 'g', '25v250')
# t: 19000
# ('25', 'v', '250')
# g:  2.5
# v: 250
# f_t38000g25v370
# t38000g25v370
# ('t38000', 'g', '25v370')
# t: 38000
# ('25', 'v', '370')
# g:  2.5
# v: 370
# f_t20000g50v210
# t20000g50v210
# ('t20000', 'g', '50v210')
# t: 20000
# ('50', 'v', '210')
# g:  5.0
# v: 210
# f_t28000g50v320
# t28000g50v320
# ('t28000', 'g', '50v320')
# t: 28000
# ('50', 'v', '320')
# g:  5.0
# v: 320
# f_t17000g40v100
# t17000g40v100
# ('t17000', 'g', '40v100')
# t: 17000
# ('40', 'v', '100')
# g:  4.0
# v: 100
# f_t19000g35v250
# t19000g35v250
# ('t19000', 'g', '35v250')
# t: 19000
# ('35', 'v', '250')
# g:  3.5
# v: 250
# f_t30000g35v240
# t30000g35v240
# ('t30000', 'g', '35v240')
# t: 30000
# ('35', 'v', '240')
# g:  3.5
# v: 240
# f_t38000g35v370
# t38000g35v370
# ('t38000', 'g', '35v370')
# t: 38000
# ('35', 'v', '370')
# g:  3.5
# v: 370
# f_t22000g45v160
# t22000g45v160
# ('t22000', 'g', '45v160')
# t: 22000
# ('45', 'v', '160')
# g:  4.5
# v: 160
# f_t37000g45v180
# t37000g45v180
# ('t37000', 'g', '45v180')
# t: 37000
# ('45', 'v', '180')
# g:  4.5
# v: 180
# f_t32000g20v130
# t32000g20v130
# ('t32000', 'g', '20v130')
# t: 32000
# ('20', 'v', '130')
# g:  2.0
# v: 130
# f_t24000g30v300
# t24000g30v300
# ('t24000', 'g', '30v300')
# t: 24000
# ('30', 'v', '300')
# g:  3.0
# v: 300
# f_t34000g45v350
# t34000g45v350
# ('t34000', 'g', '45v350')
# t: 34000
# ('45', 'v', '350')
# g:  4.5
# v: 350
# f_t29000g45v280
# t29000g45v280
# ('t29000', 'g', '45v280')
# t: 29000
# ('45', 'v', '280')
# g:  4.5
# v: 280
# f_t15000g45v270
# t15000g45v270
# ('t15000', 'g', '45v270')
# t: 15000
# ('45', 'v', '270')
# g:  4.5
# v: 270
# f_t24000g20v300
# t24000g20v300
# ('t24000', 'g', '20v300')
# t: 24000
# ('20', 'v', '300')
# g:  2.0
# v: 300
# f_t32000g30v130
# t32000g30v130
# ('t32000', 'g', '30v130')
# t: 32000
# ('30', 'v', '130')
# g:  3.0
# v: 130
# f_t35000g45v160
# t35000g45v160
# ('t35000', 'g', '45v160')
# t: 35000
# ('45', 'v', '160')
# g:  4.5
# v: 160
# f_t20000g45v180
# t20000g45v180
# ('t20000', 'g', '45v180')
# t: 20000
# ('45', 'v', '180')
# g:  4.5
# v: 180
# f_t33000g30v300
# t33000g30v300
# ('t33000', 'g', '30v300')
# t: 33000
# ('30', 'v', '300')
# g:  3.0
# v: 300
# f_t25000g20v130
# t25000g20v130
# ('t25000', 'g', '20v130')
# t: 25000
# ('20', 'v', '130')
# g:  2.0
# v: 130
# f_t23000g45v350
# t23000g45v350
# ('t23000', 'g', '45v350')
# t: 23000
# ('45', 'v', '350')
# g:  4.5
# v: 350
# f_t17000g45v290
# t17000g45v290
# ('t17000', 'g', '45v290')
# t: 17000
# ('45', 'v', '290')
# g:  4.5
# v: 290
# f_t25000g30v130
# t25000g30v130
# ('t25000', 'g', '30v130')
# t: 25000
# ('30', 'v', '130')
# g:  3.0
# v: 130
# f_t33000g20v300
# t33000g20v300
# ('t33000', 'g', '20v300')
# t: 33000
# ('20', 'v', '300')
# g:  2.0
# v: 300
# f_t37000g40v210
# t37000g40v210
# ('t37000', 'g', '40v210')
# t: 37000
# ('40', 'v', '210')
# g:  4.0
# v: 210
# f_t16000g40v330
# t16000g40v330
# ('t16000', 'g', '40v330')
# t: 16000
# ('40', 'v', '330')
# g:  4.0
# v: 330
# f_t29000g50v110
# t29000g50v110
# ('t29000', 'g', '50v110')
# t: 29000
# ('50', 'v', '110')
# g:  5.0
# v: 110
# f_t39000g35v140
# t39000g35v140
# ('t39000', 'g', '35v140')
# t: 39000
# ('35', 'v', '140')
# g:  3.5
# v: 140
# f_t27000g25v240
# t27000g25v240
# ('t27000', 'g', '25v240')
# t: 27000
# ('25', 'v', '240')
# g:  2.5
# v: 240
# f_t29000g40v110
# t29000g40v110
# ('t29000', 'g', '40v110')
# t: 29000
# ('40', 'v', '110')
# g:  4.0
# v: 110
# f_t37000g50v210
# t37000g50v210
# ('t37000', 'g', '50v210')
# t: 37000
# ('50', 'v', '210')
# g:  5.0
# v: 210
# f_t16000g50v330
# t16000g50v330
# ('t16000', 'g', '50v330')
# t: 16000
# ('50', 'v', '330')
# g:  5.0
# v: 330
# f_t27000g35v240
# t27000g35v240
# ('t27000', 'g', '35v240')
# t: 27000
# ('35', 'v', '240')
# g:  3.5
# v: 240
# f_t39000g25v140
# t39000g25v140
# ('t39000', 'g', '25v140')
# t: 39000
# ('25', 'v', '140')
# g:  2.5
# v: 140
# f_t24000g45v220
# t24000g45v220
# ('t24000', 'g', '45v220')
# t: 24000
# ('45', 'v', '220')
# g:  4.5
# v: 220
# f_t15000g20v350
# t15000g20v350
# ('t15000', 'g', '20v350')
# t: 15000
# ('20', 'v', '350')
# g:  2.0
# v: 350
# f_t21000g20v290
# t21000g20v290
# ('t21000', 'g', '20v290')
# t: 21000
# ('20', 'v', '290')
# g:  2.0
# v: 290
# f_t34000g20v270
# t34000g20v270
# ('t34000', 'g', '20v270')
# t: 34000
# ('20', 'v', '270')
# g:  2.0
# v: 270
# f_t16000g30v180
# t16000g30v180
# ('t16000', 'g', '30v180')
# t: 16000
# ('30', 'v', '180')
# g:  3.0
# v: 180
# f_t16000g20v180
# t16000g20v180
# ('t16000', 'g', '20v180')
# t: 16000
# ('20', 'v', '180')
# g:  2.0
# v: 180
# f_t15000g30v350
# t15000g30v350
# ('t15000', 'g', '30v350')
# t: 15000
# ('30', 'v', '350')
# g:  3.0
# v: 350
# f_t34000g30v270
# t34000g30v270
# ('t34000', 'g', '30v270')
# t: 34000
# ('30', 'v', '270')
# g:  3.0
# v: 270
# f_t21000g30v290
# t21000g30v290
# ('t21000', 'g', '30v290')
# t: 21000
# ('30', 'v', '290')
# g:  3.0
# v: 290
# f_t38000g50v250
# t38000g50v250
# ('t38000', 'g', '50v250')
# t: 38000
# ('50', 'v', '250')
# g:  5.0
# v: 250
# f_t25000g50v380
# t25000g50v380
# ('t25000', 'g', '50v380')
# t: 25000
# ('50', 'v', '380')
# g:  5.0
# v: 380
# f_t19000g50v370
# t19000g50v370
# ('t19000', 'g', '50v370')
# t: 19000
# ('50', 'v', '370')
# g:  5.0
# v: 370
# f_t30000g50v360
# t30000g50v360
# ('t30000', 'g', '50v360')
# t: 30000
# ('50', 'v', '360')
# g:  5.0
# v: 360
# f_t26000g40v150
# t26000g40v150
# ('t26000', 'g', '40v150')
# t: 26000
# ('40', 'v', '150')
# g:  4.0
# v: 150
# f_t36000g25v100
# t36000g25v100
# ('t36000', 'g', '25v100')
# t: 36000
# ('25', 'v', '100')
# g:  2.5
# v: 100
# f_t28000g35v200
# t28000g35v200
# ('t28000', 'g', '35v200')
# t: 28000
# ('35', 'v', '200')
# g:  3.5
# v: 200
# f_t20000g35v330
# t20000g35v330
# ('t20000', 'g', '35v330')
# t: 20000
# ('35', 'v', '330')
# g:  3.5
# v: 330
# f_t26000g50v150
# t26000g50v150
# ('t26000', 'g', '50v150')
# t: 26000
# ('50', 'v', '150')
# g:  5.0
# v: 150
# f_t38000g40v250
# t38000g40v250
# ('t38000', 'g', '40v250')
# t: 38000
# ('40', 'v', '250')
# g:  4.0
# v: 250
# f_t30000g40v360
# t30000g40v360
# ('t30000', 'g', '40v360')
# t: 30000
# ('40', 'v', '360')
# g:  4.0
# v: 360
# f_t25000g40v380
# t25000g40v380
# ('t25000', 'g', '40v380')
# t: 25000
# ('40', 'v', '380')
# g:  4.0
# v: 380
# f_t19000g40v370
# t19000g40v370
# ('t19000', 'g', '40v370')
# t: 19000
# ('40', 'v', '370')
# g:  4.0
# v: 370
# f_t28000g25v200
# t28000g25v200
# ('t28000', 'g', '25v200')
# t: 28000
# ('25', 'v', '200')
# g:  2.5
# v: 200
# f_t20000g25v330
# t20000g25v330
# ('t20000', 'g', '25v330')
# t: 20000
# ('25', 'v', '330')
# g:  2.5
# v: 330
# f_t36000g35v100
# t36000g35v100
# ('t36000', 'g', '35v100')
# t: 36000
# ('35', 'v', '100')
# g:  3.5
# v: 100
# f_t22000g45v360
# t22000g45v360
# ('t22000', 'g', '45v360')
# t: 22000
# ('45', 'v', '360')
# g:  4.5
# v: 360
# f_t37000g45v380
# t37000g45v380
# ('t37000', 'g', '45v380')
# t: 37000
# ('45', 'v', '380')
# g:  4.5
# v: 380
# f_t32000g20v330
# t32000g20v330
# ('t32000', 'g', '20v330')
# t: 32000
# ('20', 'v', '330')
# g:  2.0
# v: 330
# f_t19000g40v400
# t19000g40v400
# ('t19000', 'g', '40v400')
# t: 19000
# ('40', 'v', '400')
# g:  4.0
# v: 400
# f_t24000g30v100
# t24000g30v100
# ('t24000', 'g', '30v100')
# t: 24000
# ('30', 'v', '100')
# g:  3.0
# v: 100
# f_t34000g45v150
# t34000g45v150
# ('t34000', 'g', '45v150')
# t: 34000
# ('45', 'v', '150')
# g:  4.5
# v: 150
# f_t24000g20v100
# t24000g20v100
# ('t24000', 'g', '20v100')
# t: 24000
# ('20', 'v', '100')
# g:  2.0
# v: 100
# f_t32000g30v330
# t32000g30v330
# ('t32000', 'g', '30v330')
# t: 32000
# ('30', 'v', '330')
# g:  3.0
# v: 330
# f_t19000g50v400
# t19000g50v400
# ('t19000', 'g', '50v400')
# t: 19000
# ('50', 'v', '400')
# g:  5.0
# v: 400
# f_t36000g50v220
# t36000g50v220
# ('t36000', 'g', '50v220')
# t: 36000
# ('50', 'v', '220')
# g:  5.0
# v: 220
# f_t17000g50v300
# t17000g50v300
# ('t17000', 'g', '50v300')
# t: 17000
# ('50', 'v', '300')
# g:  5.0
# v: 300
# f_t28000g40v120
# t28000g40v120
# ('t28000', 'g', '40v120')
# t: 28000
# ('40', 'v', '120')
# g:  4.0
# v: 120
# f_t38000g25v170
# t38000g25v170
# ('t38000', 'g', '25v170')
# t: 38000
# ('25', 'v', '170')
# g:  2.5
# v: 170
# f_t26000g35v270
# t26000g35v270
# ('t26000', 'g', '35v270')
# t: 26000
# ('35', 'v', '270')
# g:  3.5
# v: 270
# f_t33000g35v290
# t33000g35v290
# ('t33000', 'g', '35v290')
# t: 33000
# ('35', 'v', '290')
# g:  3.5
# v: 290
# f_t28000g50v120
# t28000g50v120
# ('t28000', 'g', '50v120')
# t: 28000
# ('50', 'v', '120')
# g:  5.0
# v: 120
# f_t36000g40v220
# t36000g40v220
# ('t36000', 'g', '40v220')
# t: 36000
# ('40', 'v', '220')
# g:  4.0
# v: 220
# f_t17000g40v300
# t17000g40v300
# ('t17000', 'g', '40v300')
# t: 17000
# ('40', 'v', '300')
# g:  4.0
# v: 300
# f_t33000g25v290
# t33000g25v290
# ('t33000', 'g', '25v290')
# t: 33000
# ('25', 'v', '290')
# g:  2.5
# v: 290
# f_t26000g25v270
# t26000g25v270
# ('t26000', 'g', '25v270')
# t: 26000
# ('25', 'v', '270')
# g:  2.5
# v: 270
# f_t38000g35v170
# t38000g35v170
# ('t38000', 'g', '35v170')
# t: 38000
# ('35', 'v', '170')
# g:  3.5
# v: 170
# f_t28000g30v390
# t28000g30v390
# ('t28000', 'g', '30v390')
# t: 28000
# ('30', 'v', '390')
# g:  3.0
# v: 390
# f_t35000g30v240
# t35000g30v240
# ('t35000', 'g', '30v240')
# t: 35000
# ('30', 'v', '240')
# g:  3.0
# v: 240
# f_t25000g45v210
# t25000g45v210
# ('t25000', 'g', '45v210')
# t: 25000
# ('45', 'v', '210')
# g:  4.5
# v: 210
# f_t28000g20v390
# t28000g20v390
# ('t28000', 'g', '20v390')
# t: 28000
# ('20', 'v', '390')
# g:  2.0
# v: 390
# f_t35000g20v240
# t35000g20v240
# ('t35000', 'g', '20v240')
# t: 35000
# ('20', 'v', '240')
# g:  2.0
# v: 240
# f_t39000g40v260
# t39000g40v260
# ('t39000', 'g', '40v260')
# t: 39000
# ('40', 'v', '260')
# g:  4.0
# v: 260
# f_t18000g40v340
# t18000g40v340
# ('t18000', 'g', '40v340')
# t: 18000
# ('40', 'v', '340')
# g:  4.0
# v: 340
# f_t31000g40v350
# t31000g40v350
# ('t31000', 'g', '40v350')
# t: 31000
# ('40', 'v', '350')
# g:  4.0
# v: 350
# f_t32000g50v180
# t32000g50v180
# ('t32000', 'g', '50v180')
# t: 32000
# ('50', 'v', '180')
# g:  5.0
# v: 180
# f_t27000g50v160
# t27000g50v160
# ('t27000', 'g', '50v160')
# t: 27000
# ('50', 'v', '160')
# g:  5.0
# v: 160
# f_t37000g35v130
# t37000g35v130
# ('t37000', 'g', '35v130')
# t: 37000
# ('35', 'v', '130')
# g:  3.5
# v: 130
# f_t29000g25v230
# t29000g25v230
# ('t29000', 'g', '25v230')
# t: 29000
# ('25', 'v', '230')
# g:  2.5
# v: 230
# f_t21000g25v300
# t21000g25v300
# ('t21000', 'g', '25v300')
# t: 21000
# ('25', 'v', '300')
# g:  2.5
# v: 300
# f_t27000g40v160
# t27000g40v160
# ('t27000', 'g', '40v160')
# t: 27000
# ('40', 'v', '160')
# g:  4.0
# v: 160
# f_t32000g40v180
# t32000g40v180
# ('t32000', 'g', '40v180')
# t: 32000
# ('40', 'v', '180')
# g:  4.0
# v: 180
# f_t39000g50v260
# t39000g50v260
# ('t39000', 'g', '50v260')
# t: 39000
# ('50', 'v', '260')
# g:  5.0
# v: 260
# f_t31000g50v350
# t31000g50v350
# ('t31000', 'g', '50v350')
# t: 31000
# ('50', 'v', '350')
# g:  5.0
# v: 350
# f_t18000g50v340
# t18000g50v340
# ('t18000', 'g', '50v340')
# t: 18000
# ('50', 'v', '340')
# g:  5.0
# v: 340
# f_t29000g35v230
# t29000g35v230
# ('t29000', 'g', '35v230')
# t: 29000
# ('35', 'v', '230')
# g:  3.5
# v: 230
# f_t21000g35v300
# t21000g35v300
# ('t21000', 'g', '35v300')
# t: 21000
# ('35', 'v', '300')
# g:  3.5
# v: 300
# f_t37000g25v130
# t37000g25v130
# ('t37000', 'g', '25v130')
# t: 37000
# ('25', 'v', '130')
# g:  2.5
# v: 130
# f_t19000g50v170
# t19000g50v170
# ('t19000', 'g', '50v170')
# t: 19000
# ('50', 'v', '170')
# g:  5.0
# v: 170
# f_t25000g50v180
# t25000g50v180
# ('t25000', 'g', '50v180')
# t: 25000
# ('50', 'v', '180')
# g:  5.0
# v: 180
# f_t30000g50v160
# t30000g50v160
# ('t30000', 'g', '50v160')
# t: 30000
# ('50', 'v', '160')
# g:  5.0
# v: 160
# f_t26000g40v350
# t26000g40v350
# ('t26000', 'g', '40v350')
# t: 26000
# ('40', 'v', '350')
# g:  4.0
# v: 350
# f_t17000g25v220
# t17000g25v220
# ('t17000', 'g', '25v220')
# t: 17000
# ('25', 'v', '220')
# g:  2.5
# v: 220
# f_t36000g25v300
# t36000g25v300
# ('t36000', 'g', '25v300')
# t: 36000
# ('25', 'v', '300')
# g:  2.5
# v: 300
# f_t20000g35v130
# t20000g35v130
# ('t20000', 'g', '35v130')
# t: 20000
# ('35', 'v', '130')
# g:  3.5
# v: 130
# f_t26000g50v350
# t26000g50v350
# ('t26000', 'g', '50v350')
# t: 26000
# ('50', 'v', '350')
# g:  5.0
# v: 350
# f_t30000g40v160
# t30000g40v160
# ('t30000', 'g', '40v160')
# t: 30000
# ('40', 'v', '160')
# g:  4.0
# v: 160
# f_t19000g40v170
# t19000g40v170
# ('t19000', 'g', '40v170')
# t: 19000
# ('40', 'v', '170')
# g:  4.0
# v: 170
# f_t25000g40v180
# t25000g40v180
# ('t25000', 'g', '40v180')
# t: 25000
# ('40', 'v', '180')
# g:  4.0
# v: 180
# f_t20000g25v130
# t20000g25v130
# ('t20000', 'g', '25v130')
# t: 20000
# ('25', 'v', '130')
# g:  2.5
# v: 130
# f_t17000g35v220
# t17000g35v220
# ('t17000', 'g', '35v220')
# t: 17000
# ('35', 'v', '220')
# g:  3.5
# v: 220
# f_t36000g35v300
# t36000g35v300
# ('t36000', 'g', '35v300')
# t: 36000
# ('35', 'v', '300')
# g:  3.5
# v: 300
# f_t38000g35v400
# t38000g35v400
# ('t38000', 'g', '35v400')
# t: 38000
# ('35', 'v', '400')
# g:  3.5
# v: 400
# f_t15000g20v150
# t15000g20v150
# ('t15000', 'g', '20v150')
# t: 15000
# ('20', 'v', '150')
# g:  2.0
# v: 150
# f_t16000g30v380
# t16000g30v380
# ('t16000', 'g', '30v380')
# t: 16000
# ('30', 'v', '380')
# g:  3.0
# v: 380
# f_t22000g30v240
# t22000g30v240
# ('t22000', 'g', '30v240')
# t: 22000
# ('30', 'v', '240')
# g:  3.0
# v: 240
# f_t32000g45v210
# t32000g45v210
# ('t32000', 'g', '45v210')
# t: 32000
# ('45', 'v', '210')
# g:  4.5
# v: 210
# f_t38000g25v400
# t38000g25v400
# ('t38000', 'g', '25v400')
# t: 38000
# ('25', 'v', '400')
# g:  2.5
# v: 400
# f_t16000g20v380
# t16000g20v380
# ('t16000', 'g', '20v380')
# t: 16000
# ('20', 'v', '380')
# g:  2.0
# v: 380
# f_t22000g20v240
# t22000g20v240
# ('t22000', 'g', '20v240')
# t: 22000
# ('20', 'v', '240')
# g:  2.0
# v: 240
# f_t15000g30v150
# t15000g30v150
# ('t15000', 'g', '30v150')
# t: 15000
# ('30', 'v', '150')
# g:  3.0
# v: 150
# f_t16000g40v130
# t16000g40v130
# ('t16000', 'g', '40v130')
# t: 16000
# ('40', 'v', '130')
# g:  4.0
# v: 130
# f_t21000g50v220
# t21000g50v220
# ('t21000', 'g', '50v220')
# t: 21000
# ('50', 'v', '220')
# g:  5.0
# v: 220
# f_t29000g50v310
# t29000g50v310
# ('t29000', 'g', '50v310')
# t: 29000
# ('50', 'v', '310')
# g:  5.0
# v: 310
# f_t31000g35v270
# t31000g35v270
# ('t31000', 'g', '35v270')
# t: 31000
# ('35', 'v', '270')
# g:  3.5
# v: 270
# f_t18000g35v260
# t18000g35v260
# ('t18000', 'g', '35v260')
# t: 18000
# ('35', 'v', '260')
# g:  3.5
# v: 260
# f_t24000g35v290
# t24000g35v290
# ('t24000', 'g', '35v290')
# t: 24000
# ('35', 'v', '290')
# g:  3.5
# v: 290
# f_t39000g35v340
# t39000g35v340
# ('t39000', 'g', '35v340')
# t: 39000
# ('35', 'v', '340')
# g:  3.5
# v: 340
# f_t21000g40v220
# t21000g40v220
# ('t21000', 'g', '40v220')
# t: 21000
# ('40', 'v', '220')
# g:  4.0
# v: 220
# f_t29000g40v310
# t29000g40v310
# ('t29000', 'g', '40v310')
# t: 29000
# ('40', 'v', '310')
# g:  4.0
# v: 310
# f_t16000g50v130
# t16000g50v130
# ('t16000', 'g', '50v130')
# t: 16000
# ('50', 'v', '130')
# g:  5.0
# v: 130
# f_t18000g25v260
# t18000g25v260
# ('t18000', 'g', '25v260')
# t: 18000
# ('25', 'v', '260')
# g:  2.5
# v: 260
# f_t24000g25v290
# t24000g25v290
# ('t24000', 'g', '25v290')
# t: 24000
# ('25', 'v', '290')
# g:  2.5
# v: 290
# f_t31000g25v270
# t31000g25v270
# ('t31000', 'g', '25v270')
# t: 31000
# ('25', 'v', '270')
# g:  2.5
# v: 270
# f_t39000g25v340
# t39000g25v340
# ('t39000', 'g', '25v340')
# t: 39000
# ('25', 'v', '340')
# g:  2.5
# v: 340
# f_t35000g45v360
# t35000g45v360
# ('t35000', 'g', '45v360')
# t: 35000
# ('45', 'v', '360')
# g:  4.5
# v: 360
# f_t20000g45v380
# t20000g45v380
# ('t20000', 'g', '45v380')
# t: 20000
# ('45', 'v', '380')
# g:  4.5
# v: 380
# f_t33000g30v100
# t33000g30v100
# ('t33000', 'g', '30v100')
# t: 33000
# ('30', 'v', '100')
# g:  3.0
# v: 100
# f_t25000g20v330
# t25000g20v330
# ('t25000', 'g', '20v330')
# t: 25000
# ('20', 'v', '330')
# g:  2.0
# v: 330
# f_t23000g45v150
# t23000g45v150
# ('t23000', 'g', '45v150')
# t: 23000
# ('45', 'v', '150')
# g:  4.5
# v: 150
# f_t25000g30v330
# t25000g30v330
# ('t25000', 'g', '30v330')
# t: 25000
# ('30', 'v', '330')
# g:  3.0
# v: 330
# f_t33000g20v100
# t33000g20v100
# ('t33000', 'g', '20v100')
# t: 33000
# ('20', 'v', '100')
# g:  2.0
# v: 100
# f_t23000g35v280
# t23000g35v280
# ('t23000', 'g', '35v280')
# t: 23000
# ('35', 'v', '280')
# g:  3.5
# v: 280
# f_t36000g35v260
# t36000g35v260
# ('t36000', 'g', '35v260')
# t: 36000
# ('35', 'v', '260')
# g:  3.5
# v: 260
# f_t17000g35v340
# t17000g35v340
# ('t17000', 'g', '35v340')
# t: 17000
# ('35', 'v', '340')
# g:  3.5
# v: 340
# f_t28000g25v160
# t28000g25v160
# ('t28000', 'g', '25v160')
# t: 28000
# ('25', 'v', '160')
# g:  2.5
# v: 160
# f_t38000g40v130
# t38000g40v130
# ('t38000', 'g', '40v130')
# t: 38000
# ('40', 'v', '130')
# g:  4.0
# v: 130
# f_t26000g50v230
# t26000g50v230
# ('t26000', 'g', '50v230')
# t: 26000
# ('50', 'v', '230')
# g:  5.0
# v: 230
# f_t28000g35v160
# t28000g35v160
# ('t28000', 'g', '35v160')
# t: 28000
# ('35', 'v', '160')
# g:  3.5
# v: 160
# f_t36000g25v260
# t36000g25v260
# ('t36000', 'g', '25v260')
# t: 36000
# ('25', 'v', '260')
# g:  2.5
# v: 260
# f_t23000g25v280
# t23000g25v280
# ('t23000', 'g', '25v280')
# t: 23000
# ('25', 'v', '280')
# g:  2.5
# v: 280
# f_t17000g25v340
# t17000g25v340
# ('t17000', 'g', '25v340')
# t: 17000
# ('25', 'v', '340')
# g:  2.5
# v: 340
# f_t26000g40v230
# t26000g40v230
# ('t26000', 'g', '40v230')
# t: 26000
# ('40', 'v', '230')
# g:  4.0
# v: 230
# f_t38000g50v130
# t38000g50v130
# ('t38000', 'g', '50v130')
# t: 38000
# ('50', 'v', '130')
# g:  5.0
# v: 130
# f_t34000g30v110
# t34000g30v110
# ('t34000', 'g', '30v110')
# t: 34000
# ('30', 'v', '110')
# g:  3.0
# v: 110
# f_t22000g20v320
# t22000g20v320
# ('t22000', 'g', '20v320')
# t: 22000
# ('20', 'v', '320')
# g:  2.0
# v: 320
# f_t20000g40v400
# t20000g40v400
# ('t20000', 'g', '40v400')
# t: 20000
# ('40', 'v', '400')
# g:  4.0
# v: 400
# f_t27000g45v390
# t27000g45v390
# ('t27000', 'g', '45v390')
# t: 27000
# ('45', 'v', '390')
# g:  4.5
# v: 390
# f_t32000g45v370
# t32000g45v370
# ('t32000', 'g', '45v370')
# t: 32000
# ('45', 'v', '370')
# g:  4.5
# v: 370
# f_t22000g30v320
# t22000g30v320
# ('t22000', 'g', '30v320')
# t: 22000
# ('30', 'v', '320')
# g:  3.0
# v: 320
# f_t20000g50v400
# t20000g50v400
# ('t20000', 'g', '50v400')
# t: 20000
# ('50', 'v', '400')
# g:  5.0
# v: 400
# f_t34000g20v110
# t34000g20v110
# ('t34000', 'g', '20v110')
# t: 34000
# ('20', 'v', '110')
# g:  2.0
# v: 110
# f_t24000g45v140
# t24000g45v140
# ('t24000', 'g', '45v140')
# t: 24000
# ('45', 'v', '140')
# g:  4.5
# v: 140
# f_t39000g25v220
# t39000g25v220
# ('t39000', 'g', '25v220')
# t: 39000
# ('25', 'v', '220')
# g:  2.5
# v: 220
# f_t31000g25v310
# t31000g25v310
# ('t31000', 'g', '25v310')
# t: 31000
# ('25', 'v', '310')
# g:  2.5
# v: 310
# f_t18000g25v300
# t18000g25v300
# ('t18000', 'g', '25v300')
# t: 18000
# ('25', 'v', '300')
# g:  2.5
# v: 300
# f_t27000g35v120
# t27000g35v120
# ('t27000', 'g', '35v120')
# t: 27000
# ('35', 'v', '120')
# g:  3.5
# v: 120
# f_t37000g50v170
# t37000g50v170
# ('t37000', 'g', '50v170')
# t: 37000
# ('50', 'v', '170')
# g:  5.0
# v: 170
# f_t22000g50v190
# t22000g50v190
# ('t22000', 'g', '50v190')
# t: 22000
# ('50', 'v', '190')
# g:  5.0
# v: 190
# f_t15000g40v280
# t15000g40v280
# ('t15000', 'g', '40v280')
# t: 15000
# ('40', 'v', '280')
# g:  4.0
# v: 280
# f_t29000g40v270
# t29000g40v270
# ('t29000', 'g', '40v270')
# t: 29000
# ('40', 'v', '270')
# g:  4.0
# v: 270
# f_t21000g40v340
# t21000g40v340
# ('t21000', 'g', '40v340')
# t: 21000
# ('40', 'v', '340')
# g:  4.0
# v: 340
# f_t27000g25v120
# t27000g25v120
# ('t27000', 'g', '25v120')
# t: 27000
# ('25', 'v', '120')
# g:  2.5
# v: 120
# f_t39000g35v220
# t39000g35v220
# ('t39000', 'g', '35v220')
# t: 39000
# ('35', 'v', '220')
# g:  3.5
# v: 220
# f_t18000g35v300
# t18000g35v300
# ('t18000', 'g', '35v300')
# t: 18000
# ('35', 'v', '300')
# g:  3.5
# v: 300
# f_t31000g35v310
# t31000g35v310
# ('t31000', 'g', '35v310')
# t: 31000
# ('35', 'v', '310')
# g:  3.5
# v: 310
# f_t15000g50v280
# t15000g50v280
# ('t15000', 'g', '50v280')
# t: 15000
# ('50', 'v', '280')
# g:  5.0
# v: 280
# f_t29000g50v270
# t29000g50v270
# ('t29000', 'g', '50v270')
# t: 29000
# ('50', 'v', '270')
# g:  5.0
# v: 270
# f_t21000g50v340
# t21000g50v340
# ('t21000', 'g', '50v340')
# t: 21000
# ('50', 'v', '340')
# g:  5.0
# v: 340
# f_t22000g40v190
# t22000g40v190
# ('t22000', 'g', '40v190')
# t: 22000
# ('40', 'v', '190')
# g:  4.0
# v: 190
# f_t37000g40v170
# t37000g40v170
# ('t37000', 'g', '40v170')
# t: 37000
# ('40', 'v', '170')
# g:  4.0
# v: 170
# f_t38000g30v380
# t38000g30v380
# ('t38000', 'g', '30v380')
# t: 38000
# ('30', 'v', '380')
# g:  3.0
# v: 380
# f_t25000g30v250
# t25000g30v250
# ('t25000', 'g', '30v250')
# t: 25000
# ('30', 'v', '250')
# g:  3.0
# v: 250
# f_t16000g35v400
# t16000g35v400
# ('t16000', 'g', '35v400')
# t: 16000
# ('35', 'v', '400')
# g:  3.5
# v: 400
# f_t38000g20v380
# t38000g20v380
# ('t38000', 'g', '20v380')
# t: 38000
# ('20', 'v', '380')
# g:  2.0
# v: 380
# f_t25000g20v250
# t25000g20v250
# ('t25000', 'g', '20v250')
# t: 25000
# ('20', 'v', '250')
# g:  2.0
# v: 250
# f_t35000g45v200
# t35000g45v200
# ('t35000', 'g', '45v200')
# t: 35000
# ('45', 'v', '200')
# g:  4.5
# v: 200
# f_t16000g25v400
# t16000g25v400
# ('t16000', 'g', '25v400')
# t: 16000
# ('25', 'v', '400')
# g:  2.5
# v: 400
# f_t32000g30v250
# t32000g30v250
# ('t32000', 'g', '30v250')
# t: 32000
# ('30', 'v', '250')
# g:  3.0
# v: 250
# f_t15000g45v110
# t15000g45v110
# ('t15000', 'g', '45v110')
# t: 15000
# ('45', 'v', '110')
# g:  4.5
# v: 110
# f_t32000g20v250
# t32000g20v250
# ('t32000', 'g', '20v250')
# t: 32000
# ('20', 'v', '250')
# g:  2.0
# v: 250
# f_t22000g45v200
# t22000g45v200
# ('t22000', 'g', '45v200')
# t: 22000
# ('45', 'v', '200')
# g:  4.5
# v: 200
# f_t30000g35v120
# t30000g35v120
# ('t30000', 'g', '35v120')
# t: 30000
# ('35', 'v', '120')
# g:  3.5
# v: 120
# f_t19000g35v130
# t19000g35v130
# ('t19000', 'g', '35v130')
# t: 19000
# ('35', 'v', '130')
# g:  3.5
# v: 130
# f_t26000g25v310
# t26000g25v310
# ('t26000', 'g', '25v310')
# t: 26000
# ('25', 'v', '310')
# g:  2.5
# v: 310
# f_t17000g40v260
# t17000g40v260
# ('t17000', 'g', '40v260')
# t: 17000
# ('40', 'v', '260')
# g:  4.0
# v: 260
# f_t36000g40v340
# t36000g40v340
# ('t36000', 'g', '40v340')
# t: 36000
# ('40', 'v', '340')
# g:  4.0
# v: 340
# f_t20000g50v170
# t20000g50v170
# ('t20000', 'g', '50v170')
# t: 20000
# ('50', 'v', '170')
# g:  5.0
# v: 170
# f_t35000g50v190
# t35000g50v190
# ('t35000', 'g', '50v190')
# t: 35000
# ('50', 'v', '190')
# g:  5.0
# v: 190
# f_t26000g35v310
# t26000g35v310
# ('t26000', 'g', '35v310')
# t: 26000
# ('35', 'v', '310')
# g:  3.5
# v: 310
# f_t19000g25v130
# t19000g25v130
# ('t19000', 'g', '25v130')
# t: 19000
# ('25', 'v', '130')
# g:  2.5
# v: 130
# f_t30000g25v120
# t30000g25v120
# ('t30000', 'g', '25v120')
# t: 30000
# ('25', 'v', '120')
# g:  2.5
# v: 120
# f_t35000g40v190
# t35000g40v190
# ('t35000', 'g', '40v190')
# t: 35000
# ('40', 'v', '190')
# g:  4.0
# v: 190
# f_t20000g40v170
# t20000g40v170
# ('t20000', 'g', '40v170')
# t: 20000
# ('40', 'v', '170')
# ...
# t: 33000
# ('20', 'v', '250')
# g:  2.0
# v: 250
# f_t23000g45v200
# t23000g45v200
# ('t23000', 'g', '45v200')
# t: 23000
# ('45', 'v', '200')
# g:  4.5
# v: 200
# f_t35000g35v280
# t35000g35v280
# ('t35000', 'g', '35v280')
# t: 35000
# ('35', 'v', '280')
# g:  3.5
# v: 280
# f_t20000g35v260
# t20000g35v260
# ('t20000', 'g', '35v260')
# t: 20000
# ('35', 'v', '260')
# g:  3.5
# v: 260
# f_t28000g35v350
# t28000g35v350
# ('t28000', 'g', '35v350')
# t: 28000
# ('35', 'v', '350')
# g:  3.5
# v: 350
# f_t17000g25v170
# t17000g25v170
# ('t17000', 'g', '25v170')
# t: 17000
# ('25', 'v', '170')
# g:  2.5
# v: 170
# f_t19000g50v220
# t19000g50v220
# ('t19000', 'g', '50v220')
# t: 19000
# ('50', 'v', '220')
# g:  5.0
# v: 220
# f_t30000g50v230
# t30000g50v230
# ('t30000', 'g', '50v230')
# t: 30000
# ('50', 'v', '230')
# g:  5.0
# v: 230
# f_t38000g50v300
# t38000g50v300
# ('t38000', 'g', '50v300')
# t: 38000
# ('50', 'v', '300')
# g:  5.0
# v: 300
# f_t17000g35v170
# t17000g35v170
# ('t17000', 'g', '35v170')
# t: 17000
# ('35', 'v', '170')
# g:  3.5
# v: 170
# f_t20000g25v260
# t20000g25v260
# ('t20000', 'g', '25v260')
# t: 20000
# ('25', 'v', '260')
# g:  2.5
# v: 260
# f_t35000g25v280
# t35000g25v280
# ('t35000', 'g', '25v280')
# t: 35000
# ('25', 'v', '280')
# g:  2.5
# v: 280
# f_t28000g25v350
# t28000g25v350
# ('t28000', 'g', '25v350')
# t: 28000
# ('25', 'v', '350')
# g:  2.5
# v: 350
# f_t30000g40v230
# t30000g40v230
# ('t30000', 'g', '40v230')
# t: 30000
# ('40', 'v', '230')
# g:  4.0
# v: 230
# f_t19000g40v220
# t19000g40v220
# ('t19000', 'g', '40v220')
# t: 19000
# ('40', 'v', '220')
# g:  4.0
# v: 220
# f_t38000g40v300
# t38000g40v300
# ('t38000', 'g', '40v300')
# t: 38000
# ('40', 'v', '300')
# g:  4.0
# v: 300
# f_t22000g30v110
# t22000g30v110
# ('t22000', 'g', '30v110')
# t: 22000
# ('30', 'v', '110')
# g:  3.0
# v: 110
# f_t34000g20v320
# t34000g20v320
# ('t34000', 'g', '20v320')
# t: 34000
# ('20', 'v', '320')
# g:  2.0
# v: 320
# f_t36000g40v400
# t36000g40v400
# ('t36000', 'g', '40v400')
# t: 36000
# ('40', 'v', '400')
# g:  4.0
# v: 400
# f_t15000g20v200
# t15000g20v200
# ('t15000', 'g', '20v200')
# t: 15000
# ('20', 'v', '200')
# g:  2.0
# v: 200
# f_t31000g45v390
# t31000g45v390
# ('t31000', 'g', '45v390')
# t: 31000
# ('45', 'v', '390')
# g:  4.5
# v: 390
# f_t18000g45v380
# t18000g45v380
# ('t18000', 'g', '45v380')
# t: 18000
# ('45', 'v', '380')
# g:  4.5
# v: 380
# f_t24000g45v370
# t24000g45v370
# ('t24000', 'g', '45v370')
# t: 24000
# ('45', 'v', '370')
# g:  4.5
# v: 370
# f_t34000g30v320
# t34000g30v320
# ('t34000', 'g', '30v320')
# t: 34000
# ('30', 'v', '320')
# g:  3.0
# v: 320
# f_t36000g50v400
# t36000g50v400
# ('t36000', 'g', '50v400')
# t: 36000
# ('50', 'v', '400')
# g:  5.0
# v: 400
# f_t15000g30v200
# t15000g30v200
# ('t15000', 'g', '30v200')
# t: 15000
# ('30', 'v', '200')
# g:  3.0
# v: 200
# f_t22000g20v110
# t22000g20v110
# ('t22000', 'g', '20v110')
# t: 22000
# ('20', 'v', '110')
# g:  2.0
# v: 110
# f_t32000g45v140
# t32000g45v140
# ('t32000', 'g', '45v140')
# t: 32000
# ('45', 'v', '140')
# g:  4.5
# v: 140
# f_t23000g20v320
# t23000g20v320
# ('t23000', 'g', '20v320')
# t: 23000
# ('20', 'v', '320')
# g:  2.0
# v: 320
# f_t21000g40v400
# t21000g40v400
# ('t21000', 'g', '40v400')
# t: 21000
# ('40', 'v', '400')
# g:  4.0
# v: 400
# f_t35000g30v110
# t35000g30v110
# ('t35000', 'g', '30v110')
# t: 35000
# ('30', 'v', '110')
# g:  3.0
# v: 110
# f_t26000g45v390
# t26000g45v390
# ('t26000', 'g', '45v390')
# t: 26000
# ('45', 'v', '390')
# g:  4.5
# v: 390
# f_t33000g45v370
# t33000g45v370
# ('t33000', 'g', '45v370')
# t: 33000
# ('45', 'v', '370')
# g:  4.5
# v: 370
# f_t35000g20v110
# t35000g20v110
# ('t35000', 'g', '20v110')
# t: 35000
# ('20', 'v', '110')
# g:  2.0
# v: 110
# f_t23000g30v320
# t23000g30v320
# ('t23000', 'g', '30v320')
# t: 23000
# ('30', 'v', '320')
# g:  3.0
# v: 320
# f_t21000g50v400
# t21000g50v400
# ('t21000', 'g', '50v400')
# t: 21000
# ('50', 'v', '400')
# g:  5.0
# v: 400
# f_t25000g45v140
# t25000g45v140
# ('t25000', 'g', '45v140')
# t: 25000
# ('45', 'v', '140')
# g:  4.5
# v: 140
# f_t15000g25v190
# t15000g25v190
# ('t15000', 'g', '25v190')
# t: 15000
# ('25', 'v', '190')
# g:  2.5
# v: 190
# f_t29000g25v160
# t29000g25v160
# ('t29000', 'g', '25v160')
# t: 29000
# ('25', 'v', '160')
# g:  2.5
# v: 160
# f_t22000g35v280
# t22000g35v280
# ('t22000', 'g', '35v280')
# t: 22000
# ('35', 'v', '280')
# g:  3.5
# v: 280
# f_t37000g35v260
# t37000g35v260
# ('t37000', 'g', '35v260')
# t: 37000
# ('35', 'v', '260')
# g:  3.5
# v: 260
# f_t16000g35v340
# t16000g35v340
# ('t16000', 'g', '35v340')
# t: 16000
# ('35', 'v', '340')
# g:  3.5
# v: 340
# f_t27000g50v230
# t27000g50v230
# ('t27000', 'g', '50v230')
# t: 27000
# ('50', 'v', '230')
# g:  5.0
# v: 230
# f_t39000g40v130
# t39000g40v130
# ('t39000', 'g', '40v130')
# t: 39000
# ('40', 'v', '130')
# g:  4.0
# v: 130
# f_t37000g25v260
# t37000g25v260
# ('t37000', 'g', '25v260')
# t: 37000
# ('25', 'v', '260')
# g:  2.5
# v: 260
# f_t22000g25v280
# t22000g25v280
# ('t22000', 'g', '25v280')
# t: 22000
# ('25', 'v', '280')
# g:  2.5
# v: 280
# f_t16000g25v340
# t16000g25v340
# ('t16000', 'g', '25v340')
# t: 16000
# ('25', 'v', '340')
# g:  2.5
# v: 340
# f_t15000g35v190
# t15000g35v190
# ('t15000', 'g', '35v190')
# t: 15000
# ('35', 'v', '190')
# g:  3.5
# v: 190
# f_t29000g35v160
# t29000g35v160
# ('t29000', 'g', '35v160')
# t: 29000
# ('35', 'v', '160')
# g:  3.5
# v: 160
# f_t39000g50v130
# t39000g50v130
# ('t39000', 'g', '50v130')
# t: 39000
# ('50', 'v', '130')
# g:  5.0
# v: 130
# f_t27000g40v230
# t27000g40v230
# ('t27000', 'g', '40v230')
# t: 27000
# ('40', 'v', '230')
# g:  4.0
# v: 230
# f_t39000g30v380
# t39000g30v380
# ('t39000', 'g', '30v380')
# t: 39000
# ('30', 'v', '380')
# g:  3.0
# v: 380
# f_t24000g30v250
# t24000g30v250
# ('t24000', 'g', '30v250')
# t: 24000
# ('30', 'v', '250')
# g:  3.0
# v: 250
# f_t17000g35v400
# t17000g35v400
# ('t17000', 'g', '35v400')
# t: 17000
# ('35', 'v', '400')
# g:  3.5
# v: 400
# f_t39000g20v380
# t39000g20v380
# ('t39000', 'g', '20v380')
# t: 39000
# ('20', 'v', '380')
# g:  2.0
# v: 380
# f_t24000g20v250
# t24000g20v250
# ('t24000', 'g', '20v250')
# t: 24000
# ('20', 'v', '250')
# g:  2.0
# v: 250
# f_t15000g45v320
# t15000g45v320
# ('t15000', 'g', '45v320')
# t: 15000
# ('45', 'v', '320')
# g:  4.5
# v: 320
# f_t17000g25v400
# t17000g25v400
# ('t17000', 'g', '25v400')
# t: 17000
# ('25', 'v', '400')
# g:  2.5
# v: 400
# f_t34000g45v200
# t34000g45v200
# ('t34000', 'g', '45v200')
# t: 34000
# ('45', 'v', '200')
# g:  4.5
# v: 200
# f_t26000g35v120
# t26000g35v120
# ('t26000', 'g', '35v120')
# t: 26000
# ('35', 'v', '120')
# g:  3.5
# v: 120
# f_t38000g25v220
# t38000g25v220
# ('t38000', 'g', '25v220')
# t: 38000
# ('25', 'v', '220')
# g:  2.5
# v: 220
# f_t30000g25v310
# t30000g25v310
# ('t30000', 'g', '25v310')
# t: 30000
# ('25', 'v', '310')
# g:  2.5
# v: 310
# f_t19000g25v300
# t19000g25v300
# ('t19000', 'g', '25v300')
# t: 19000
# ('25', 'v', '300')
# g:  2.5
# v: 300
# f_t28000g40v270
# t28000g40v270
# ('t28000', 'g', '40v270')
# t: 28000
# ('40', 'v', '270')
# g:  4.0
# v: 270
# f_t20000g40v340
# t20000g40v340
# ('t20000', 'g', '40v340')
# t: 20000
# ('40', 'v', '340')
# g:  4.0
# v: 340
# f_t36000g50v170
# t36000g50v170
# ('t36000', 'g', '50v170')
# t: 36000
# ('50', 'v', '170')
# g:  5.0
# v: 170
# f_t23000g50v190
# t23000g50v190
# ('t23000', 'g', '50v190')
# t: 23000
# ('50', 'v', '190')
# g:  5.0
# v: 190
# f_t38000g35v220
# t38000g35v220
# ('t38000', 'g', '35v220')
# t: 38000
# ('35', 'v', '220')
# g:  3.5
# v: 220
# f_t19000g35v300
# t19000g35v300
# ('t19000', 'g', '35v300')
# t: 19000
# ('35', 'v', '300')
# g:  3.5
# v: 300
# f_t30000g35v310
# t30000g35v310
# ('t30000', 'g', '35v310')
# t: 30000
# ('35', 'v', '310')
# g:  3.5
# v: 310
# f_t26000g25v120
# t26000g25v120
# ('t26000', 'g', '25v120')
# t: 26000
# ('25', 'v', '120')
# g:  2.5
# v: 120
# f_t23000g40v190
# t23000g40v190
# ('t23000', 'g', '40v190')
# t: 23000
# ('40', 'v', '190')
# g:  4.0
# v: 190
# f_t36000g40v170
# t36000g40v170
# ('t36000', 'g', '40v170')
# t: 36000
# ('40', 'v', '170')
# g:  4.0
# v: 170
# f_t28000g50v270
# t28000g50v270
# ('t28000', 'g', '50v270')
# t: 28000
# ('50', 'v', '270')
# g:  5.0
# v: 270
# f_t20000g50v340
# t20000g50v340
# ('t20000', 'g', '50v340')
# t: 20000
# ('50', 'v', '340')
# g:  5.0
# v: 340
# f_t39000g35v400
# t39000g35v400
# ('t39000', 'g', '35v400')
# t: 39000
# ('35', 'v', '400')
# g:  3.5
# v: 400
# f_t17000g30v380
# t17000g30v380
# ('t17000', 'g', '30v380')
# t: 17000
# ('30', 'v', '380')
# g:  3.0
# v: 380
# f_t23000g30v240
# t23000g30v240
# ('t23000', 'g', '30v240')
# t: 23000
# ('30', 'v', '240')
# g:  3.0
# v: 240
# f_t33000g45v210
# t33000g45v210
# ('t33000', 'g', '45v210')
# t: 33000
# ('45', 'v', '210')
# g:  4.5
# v: 210
# f_t39000g25v400
# t39000g25v400
# ('t39000', 'g', '25v400')
# t: 39000
# ('25', 'v', '400')
# g:  2.5
# v: 400
# f_t17000g20v380
# t17000g20v380
# ('t17000', 'g', '20v380')
# t: 17000
# ('20', 'v', '380')
# g:  2.0
# v: 380
# f_t23000g20v240
# t23000g20v240
# ('t23000', 'g', '20v240')
# t: 23000
# ('20', 'v', '240')
# g:  2.0
# v: 240
# f_t27000g40v350
# t27000g40v350
# ('t27000', 'g', '40v350')
# t: 27000
# ('40', 'v', '350')
# g:  4.0
# v: 350
# f_t18000g50v170
# t18000g50v170
# ('t18000', 'g', '50v170')
# t: 18000
# ('50', 'v', '170')
# g:  5.0
# v: 170
# f_t24000g50v180
# t24000g50v180
# ('t24000', 'g', '50v180')
# t: 24000
# ('50', 'v', '180')
# g:  5.0
# v: 180
# f_t31000g50v160
# t31000g50v160
# ('t31000', 'g', '50v160')
# t: 31000
# ('50', 'v', '160')
# g:  5.0
# v: 160
# f_t21000g35v130
# t21000g35v130
# ('t21000', 'g', '35v130')
# t: 21000
# ('35', 'v', '130')
# g:  3.5
# v: 130
# f_t16000g25v220
# t16000g25v220
# ('t16000', 'g', '25v220')
# t: 16000
# ('25', 'v', '220')
# g:  2.5
# v: 220
# f_t37000g25v300
# t37000g25v300
# ('t37000', 'g', '25v300')
# t: 37000
# ('25', 'v', '300')
# g:  2.5
# v: 300
# f_t31000g40v160
# t31000g40v160
# ('t31000', 'g', '40v160')
# t: 31000
# ('40', 'v', '160')
# g:  4.0
# v: 160
# f_t18000g40v170
# t18000g40v170
# ('t18000', 'g', '40v170')
# t: 18000
# ('40', 'v', '170')
# g:  4.0
# v: 170
# f_t24000g40v180
# t24000g40v180
# ('t24000', 'g', '40v180')
# t: 24000
# ('40', 'v', '180')
# g:  4.0
# v: 180
# f_t27000g50v350
# t27000g50v350
# ('t27000', 'g', '50v350')
# t: 27000
# ('50', 'v', '350')
# g:  5.0
# v: 350
# f_t16000g35v220
# t16000g35v220
# ('t16000', 'g', '35v220')
# t: 16000
# ('35', 'v', '220')
# g:  3.5
# v: 220
# f_t37000g35v300
# t37000g35v300
# ('t37000', 'g', '35v300')
# t: 37000
# ('35', 'v', '300')
# g:  3.5
# v: 300
# f_t21000g25v130
# t21000g25v130
# ('t21000', 'g', '25v130')
# t: 21000
# ('25', 'v', '130')
# g:  2.5
# v: 130
# f_t34000g45v360
# t34000g45v360
# ('t34000', 'g', '45v360')
# t: 34000
# ('45', 'v', '360')
# g:  4.5
# v: 360
# f_t21000g45v380
# t21000g45v380
# ('t21000', 'g', '45v380')
# t: 21000
# ('45', 'v', '380')
# g:  4.5
# v: 380
# f_t15000g45v240
# t15000g45v240
# ('t15000', 'g', '45v240')
# t: 15000
# ('45', 'v', '240')
# g:  4.5
# v: 240
# f_t24000g20v330
# t24000g20v330
# ('t24000', 'g', '20v330')
# t: 24000
# ('20', 'v', '330')
# g:  2.0
# v: 330
# f_t32000g30v100
# t32000g30v100
# ('t32000', 'g', '30v100')
# t: 32000
# ('30', 'v', '100')
# g:  3.0
# v: 100
# f_t22000g45v150
# t22000g45v150
# ('t22000', 'g', '45v150')
# t: 22000
# ('45', 'v', '150')
# g:  4.5
# v: 150
# f_t32000g20v100
# t32000g20v100
# ('t32000', 'g', '20v100')
# t: 32000
# ('20', 'v', '100')
# g:  2.0
# v: 100
# f_t24000g30v330
# t24000g30v330
# ('t24000', 'g', '30v330')
# t: 24000
# ('30', 'v', '330')
# g:  3.0
# v: 330
# f_t20000g50v220
# t20000g50v220
# ('t20000', 'g', '50v220')
# t: 20000
# ('50', 'v', '220')
# g:  5.0
# v: 220
# f_t28000g50v310
# t28000g50v310
# ('t28000', 'g', '50v310')
# t: 28000
# ('50', 'v', '310')
# g:  5.0
# v: 310
# f_t17000g40v130
# t17000g40v130
# ('t17000', 'g', '40v130')
# t: 17000
# ('40', 'v', '130')
# g:  4.0
# v: 130
# f_t30000g35v270
# t30000g35v270
# ('t30000', 'g', '35v270')
# t: 30000
# ('35', 'v', '270')
# g:  3.5
# v: 270
# f_t19000g35v260
# t19000g35v260
# ('t19000', 'g', '35v260')
# t: 19000
# ('35', 'v', '260')
# g:  3.5
# v: 260
# f_t25000g35v290
# t25000g35v290
# ('t25000', 'g', '35v290')
# t: 25000
# ('35', 'v', '290')
# g:  3.5
# v: 290
# f_t38000g35v340
# t38000g35v340
# ('t38000', 'g', '35v340')
# t: 38000
# ('35', 'v', '340')
# g:  3.5
# v: 340
# f_t17000g50v130
# t17000g50v130
# ('t17000', 'g', '50v130')
# t: 17000
# ('50', 'v', '130')
# g:  5.0
# v: 130
# f_t20000g40v220
# t20000g40v220
# ('t20000', 'g', '40v220')
# t: 20000
# ('40', 'v', '220')
# g:  4.0
# v: 220
# f_t28000g40v310
# t28000g40v310
# ('t28000', 'g', '40v310')
# t: 28000
# ('40', 'v', '310')
# g:  4.0
# v: 310
# f_t19000g25v260
# t19000g25v260
# ('t19000', 'g', '25v260')
# t: 19000
# ('25', 'v', '260')
# g:  2.5
# v: 260
# f_t25000g25v290
# t25000g25v290
# ('t25000', 'g', '25v290')
# t: 25000
# ('25', 'v', '290')
# g:  2.5
# v: 290
# f_t30000g25v270
# t30000g25v270
# ('t30000', 'g', '25v270')
# t: 30000
# ('25', 'v', '270')
# g:  2.5
# v: 270
# f_t38000g25v340
# t38000g25v340
# ('t38000', 'g', '25v340')
# t: 38000
# ('25', 'v', '340')
# g:  2.5
# v: 340
# f_t29000g40v120
# t29000g40v120
# ('t29000', 'g', '40v120')
# t: 29000
# ('40', 'v', '120')
# g:  4.0
# v: 120
# f_t37000g50v220
# t37000g50v220
# ('t37000', 'g', '50v220')
# t: 37000
# ('50', 'v', '220')
# g:  5.0
# v: 220
# f_t16000g50v300
# t16000g50v300
# ('t16000', 'g', '50v300')
# t: 16000
# ('50', 'v', '300')
# g:  5.0
# v: 300
# f_t27000g35v270
# t27000g35v270
# ('t27000', 'g', '35v270')
# t: 27000
# ('35', 'v', '270')
# g:  3.5
# v: 270
# f_t32000g35v290
# t32000g35v290
# ('t32000', 'g', '35v290')
# t: 32000
# ('35', 'v', '290')
# g:  3.5
# v: 290
# f_t39000g25v170
# t39000g25v170
# ('t39000', 'g', '25v170')
# t: 39000
# ('25', 'v', '170')
# g:  2.5
# v: 170
# f_t37000g40v220
# t37000g40v220
# ('t37000', 'g', '40v220')
# t: 37000
# ('40', 'v', '220')
# g:  4.0
# v: 220
# f_t16000g40v300
# t16000g40v300
# ('t16000', 'g', '40v300')
# t: 16000
# ('40', 'v', '300')
# g:  4.0
# v: 300
# f_t29000g50v120
# t29000g50v120
# ('t29000', 'g', '50v120')
# t: 29000
# ('50', 'v', '120')
# g:  5.0
# v: 120
# f_t39000g35v170
# t39000g35v170
# ('t39000', 'g', '35v170')
# t: 39000
# ('35', 'v', '170')
# g:  3.5
# v: 170
# f_t32000g25v290
# t32000g25v290
# ('t32000', 'g', '25v290')
# t: 32000
# ('25', 'v', '290')
# g:  2.5
# v: 290
# f_t27000g25v270
# t27000g25v270
# ('t27000', 'g', '25v270')
# t: 27000
# ('25', 'v', '270')
# g:  2.5
# v: 270
# f_t23000g45v360
# t23000g45v360
# ('t23000', 'g', '45v360')
# t: 23000
# ('45', 'v', '360')
# g:  4.5
# v: 360
# f_t36000g45v380
# t36000g45v380
# ('t36000', 'g', '45v380')
# t: 36000
# ('45', 'v', '380')
# g:  4.5
# v: 380
# f_t25000g30v100
# t25000g30v100
# ('t25000', 'g', '30v100')
# t: 25000
# ('30', 'v', '100')
# g:  3.0
# v: 100
# f_t33000g20v330
# t33000g20v330
# ('t33000', 'g', '20v330')
# t: 33000
# ('20', 'v', '330')
# g:  2.0
# v: 330
# f_t18000g40v400
# t18000g40v400
# ('t18000', 'g', '40v400')
# t: 18000
# ('40', 'v', '400')
# g:  4.0
# v: 400
# f_t35000g45v150
# t35000g45v150
# ('t35000', 'g', '45v150')
# t: 35000
# ('45', 'v', '150')
# g:  4.5
# v: 150
# f_t33000g30v330
# t33000g30v330
# ('t33000', 'g', '30v330')
# t: 33000
# ('30', 'v', '330')
# g:  3.0
# v: 330
# f_t18000g50v400
# t18000g50v400
# ('t18000', 'g', '50v400')
# t: 18000
# ('50', 'v', '400')
# g:  5.0
# v: 400
# f_t25000g20v100
# t25000g20v100
# ('t25000', 'g', '20v100')
# t: 25000
# ('20', 'v', '100')
# g:  2.0
# v: 100
# f_t33000g50v180
# t33000g50v180
# ('t33000', 'g', '50v180')
# t: 33000
# ('50', 'v', '180')
# g:  5.0
# v: 180
# f_t26000g50v160
# t26000g50v160
# ('t26000', 'g', '50v160')
# t: 26000
# ('50', 'v', '160')
# g:  5.0
# v: 160
# f_t38000g40v260
# t38000g40v260
# ('t38000', 'g', '40v260')
# t: 38000
# ('40', 'v', '260')
# g:  4.0
# v: 260
# f_t19000g40v340
# t19000g40v340
# ('t19000', 'g', '40v340')
# t: 19000
# ('40', 'v', '340')
# g:  4.0
# v: 340
# f_t30000g40v350
# t30000g40v350
# ('t30000', 'g', '40v350')
# t: 30000
# ('40', 'v', '350')
# g:  4.0
# v: 350
# f_t28000g25v230
# t28000g25v230
# ('t28000', 'g', '25v230')
# t: 28000
# ('25', 'v', '230')
# g:  2.5
# v: 230
# f_t20000g25v300
# t20000g25v300
# ('t20000', 'g', '25v300')
# t: 20000
# ('25', 'v', '300')
# g:  2.5
# v: 300
# f_t36000g35v130
# t36000g35v130
# ('t36000', 'g', '35v130')
# t: 36000
# ('35', 'v', '130')
# g:  3.5
# v: 130
# f_t38000g50v260
# t38000g50v260
# ('t38000', 'g', '50v260')
# t: 38000
# ('50', 'v', '260')
# g:  5.0
# v: 260
# f_t30000g50v350
# t30000g50v350
# ('t30000', 'g', '50v350')
# t: 30000
# ('50', 'v', '350')
# g:  5.0
# v: 350
# f_t19000g50v340
# t19000g50v340
# ('t19000', 'g', '50v340')
# t: 19000
# ('50', 'v', '340')
# g:  5.0
# v: 340
# f_t26000g40v160
# t26000g40v160
# ('t26000', 'g', '40v160')
# t: 26000
# ('40', 'v', '160')
# g:  4.0
# v: 160
# f_t33000g40v180
# t33000g40v180
# ('t33000', 'g', '40v180')
# t: 33000
# ('40', 'v', '180')
# g:  4.0
# v: 180
# f_t36000g25v130
# t36000g25v130
# ('t36000', 'g', '25v130')
# t: 36000
# ('25', 'v', '130')
# g:  2.5
# v: 130
# f_t28000g35v230
# t28000g35v230
# ('t28000', 'g', '35v230')
# t: 28000
# ('35', 'v', '230')
# g:  3.5
# v: 230
# f_t20000g35v300
# t20000g35v300
# ('t20000', 'g', '35v300')
# t: 20000
# ('35', 'v', '300')
# g:  3.5
# v: 300
# f_t15000g30v360
# t15000g30v360
# ('t15000', 'g', '30v360')
# t: 15000
# ('30', 'v', '360')
# g:  3.0
# v: 360
# f_t29000g30v390
# t29000g30v390
# ('t29000', 'g', '30v390')
# t: 29000
# ('30', 'v', '390')
# g:  3.0
# v: 390
# f_t34000g30v240
# t34000g30v240
# ('t34000', 'g', '30v240')
# t: 34000
# ('30', 'v', '240')
# g:  3.0
# v: 240
# f_t24000g45v210
# t24000g45v210
# ('t24000', 'g', '45v210')
# t: 24000
# ('45', 'v', '210')
# g:  4.5
# v: 210
# f_t15000g20v360
# t15000g20v360
# ('t15000', 'g', '20v360')
# t: 15000
# ('20', 'v', '360')
# g:  2.0
# v: 360
# f_t29000g20v390
# t29000g20v390
# ('t29000', 'g', '20v390')
# t: 29000
# ('20', 'v', '390')
# g:  2.0
# v: 390
# f_t34000g20v240
# t34000g20v240
# ('t34000', 'g', '20v240')
# t: 34000
# ('20', 'v', '240')
# g:  2.0
# v: 240

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, plot_confusion_matrix

scaler = StandardScaler()
scaler.fit(X)
X_s = scaler.transform(X)

scaler2 = StandardScaler()
scaler2.fit(y)
y_s = scaler2.transform(y)

# %% [markdown]
# ## Training, testing and validation sets

# %%
def train_val_test_split(X, y, train_size, val_size, test_size, random_state = 1):
    if train_size + val_size + test_size != 1.0:
        print("Incorrect sizes!")
        return None
    
    X_tmp, X_test, y_tmp, y_test = train_test_split(X, y, test_size = test_size, random_state=random_state)
    X_train, X_val, y_train, y_val = train_test_split(X_tmp, y_tmp, test_size = val_size/(test_size + train_size), random_state=random_state)
    return X_train, X_val, X_test, y_train, y_val, y_test

# %%
X_train, X_val, X_test, y_train, y_val, y_test = train_val_test_split(X_s, y_s, .8, .1, .1)

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
print(X_val.shape, y_val.shape)
# Out:
# (4339, 201) (4339, 3)
# (543, 201) (543, 3)
# (543, 201) (543, 3)

# %% [markdown]
# # Convolutional neural network

# %%
# about activation functions: https://datascience.stackexchange.com/questions/47751/what-activation-function-should-i-use-for-a-specific-regression-problem

# %%
# https://colab.research.google.com/drive/1zjh0tUPYJYgJJunpLC9fW5uf--O0LKeZ?usp=sharing#scrollTo=ud_tq1A0Ffvl

time_steps = X.shape[1]
input_dimension = 1

# %%
sample_size = X_train.shape[0]
X_train_reshaped = X_train.reshape((sample_size, time_steps, input_dimension))
sample_size = X_val.shape[0]
X_val_reshaped = X_val.reshape((sample_size, time_steps, input_dimension))
sample_size = X_test.shape[0]
X_test_reshaped = X_test.reshape((sample_size, time_steps, input_dimension))

# %%
print(X_train_reshaped.shape)
print(X_val_reshaped.shape)
print(X_test_reshaped.shape)
# Out:
# (4339, 201, 1)
# (543, 201, 1)
# (543, 201, 1)

# %% [markdown]
# # Histograms
# *****

# %%
def histograms_params(train, test, val, bins, labels, title=None):
    plt.figure()
    plt.hist(train, bins='auto', label=labels[0])
    if val is not None:
        plt.hist(val, bins='auto', label=labels[1])
    if test is not None:
        plt.hist(test, bins='auto', label=labels[2], alpha=0.3)
    
    if title is not None:
        plt.title(title)
    plt.legend(loc="best")
    plt.show()

# %%
histograms_params(y_train[:,0], y_val[:,0], y_test[:,0], 0, ["train", "test", "val"])
histograms_params(y_train[:,1], y_val[:,1], y_test[:,1], 0, ["train", "test", "val"], "Log g")
histograms_params(y_train[:,2], y_val[:,2], y_test[:,2], 0, ["train", "test", "val"], "v rot")

# %%
import tensorflow as tf
import keras

# %%
def build_conv1D_model():
    n_timesteps = X_train_reshaped.shape[1] #210
    n_features  = X_train_reshaped.shape[2] #1 
    model = keras.Sequential(name="model_conv1D")
    model.add(keras.layers.Input(shape=(n_timesteps,n_features)))
    model.add(keras.layers.Conv1D(filters=32, kernel_size=7, activation='relu', name="Conv1D_1"))
 
    model.add(keras.layers.Conv1D(filters=16, kernel_size=3, activation='relu', name="Conv1D_2"))
    tf.keras.layers.BatchNormalization()
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(32, activation= "selu", name="Dense_1"))
    model.add(keras.layers.Dense(3, activation = "linear", name="Dense_4"))


    optimizer = tf.keras.optimizers.RMSprop(0.001)

    l = tf.keras.losses.LogCosh()
    
    
    model.compile(loss='mse',optimizer=optimizer,metrics=['mse'])
    return model

model_conv1D = build_conv1D_model()
model_conv1D.summary()
# Out:
# Model: "model_conv1D"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Conv1D_1 (Conv1D)            (None, 195, 32)           256
# _________________________________________________________________
# Conv1D_2 (Conv1D)            (None, 193, 16)           1552
# _________________________________________________________________
# flatten (Flatten)            (None, 3088)              0
# _________________________________________________________________
# Dense_1 (Dense)              (None, 32)                98848
# _________________________________________________________________
# Dense_4 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 100,755
# Trainable params: 100,755
# Non-trainable params: 0
# _________________________________________________________________

# %%
ep = 50
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', 
                                                patience=5)
history = model_conv1D.fit(X_train_reshaped, y_train, epochs=ep,
                    validation_data = (X_val_reshaped, y_val), 
                           verbose=1, callbacks=[callback])
# Out:
# Epoch 1/50
# 136/136 [==============================] - 3s 14ms/step - loss: 0.4838 - mse: 0.4838 - val_loss: 0.2815 - val_mse: 0.2815
# Epoch 2/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.1420 - mse: 0.1420 - val_loss: 0.1344 - val_mse: 0.1344
# Epoch 3/50
# 136/136 [==============================] - 1s 8ms/step - loss: 0.1182 - mse: 0.1182 - val_loss: 0.0968 - val_mse: 0.0968
# Epoch 4/50
# 136/136 [==============================] - 1s 8ms/step - loss: 0.1084 - mse: 0.1084 - val_loss: 0.1050 - val_mse: 0.1050
# Epoch 5/50
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0966 - mse: 0.0966 - val_loss: 0.0935 - val_mse: 0.0935
# Epoch 6/50
# 136/136 [==============================] - 1s 10ms/step - loss: 0.0928 - mse: 0.0928 - val_loss: 0.0988 - val_mse: 0.0988
# Epoch 7/50
# 136/136 [==============================] - 2s 14ms/step - loss: 0.0879 - mse: 0.0879 - val_loss: 0.1139 - val_mse: 0.1139
# Epoch 8/50
# 136/136 [==============================] - 2s 12ms/step - loss: 0.0822 - mse: 0.0822 - val_loss: 0.0780 - val_mse: 0.0780
# Epoch 9/50
# 136/136 [==============================] - 2s 14ms/step - loss: 0.0799 - mse: 0.0799 - val_loss: 0.1039 - val_mse: 0.1039
# Epoch 10/50
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0773 - mse: 0.0773 - val_loss: 0.0716 - val_mse: 0.0716
# Epoch 11/50
# 136/136 [==============================] - 2s 12ms/step - loss: 0.0730 - mse: 0.0730 - val_loss: 0.0853 - val_mse: 0.0853
# Epoch 12/50
# 136/136 [==============================] - 3s 20ms/step - loss: 0.0720 - mse: 0.0720 - val_loss: 0.0729 - val_mse: 0.0729
# Epoch 13/50
# 136/136 [==============================] - 2s 15ms/step - loss: 0.0720 - mse: 0.0720 - val_loss: 0.0857 - val_mse: 0.0857
# Epoch 14/50
# 136/136 [==============================] - 2s 18ms/step - loss: 0.0666 - mse: 0.0666 - val_loss: 0.0678 - val_mse: 0.0678
# Epoch 15/50
# 136/136 [==============================] - 2s 15ms/step - loss: 0.0623 - mse: 0.0623 - val_loss: 0.0619 - val_mse: 0.0619
# Epoch 16/50
# 136/136 [==============================] - 2s 13ms/step - loss: 0.0631 - mse: 0.0631 - val_loss: 0.0738 - val_mse: 0.0738
# Epoch 17/50
# 136/136 [==============================] - 2s 13ms/step - loss: 0.0579 - mse: 0.0579 - val_loss: 0.0626 - val_mse: 0.0626
# Epoch 18/50
# 136/136 [==============================] - 2s 13ms/step - loss: 0.0613 - mse: 0.0613 - val_loss: 0.0635 - val_mse: 0.0635
# Epoch 19/50
# 136/136 [==============================] - 2s 13ms/step - loss: 0.0596 - mse: 0.0596 - val_loss: 0.0619 - val_mse: 0.0619
# Epoch 20/50
# 136/136 [==============================] - 2s 13ms/step - loss: 0.0577 - mse: 0.0577 - val_loss: 0.0567 - val_mse: 0.0567
# Epoch 21/50
# 136/136 [==============================] - 2s 14ms/step - loss: 0.0563 - mse: 0.0563 - val_loss: 0.0590 - val_mse: 0.0590
# Epoch 22/50
# 136/136 [==============================] - 2s 16ms/step - loss: 0.0553 - mse: 0.0553 - val_loss: 0.0545 - val_mse: 0.0545
# Epoch 23/50
# 136/136 [==============================] - 2s 14ms/step - loss: 0.0533 - mse: 0.0533 - val_loss: 0.0637 - val_mse: 0.0637
# Epoch 24/50
# 136/136 [==============================] - 2s 13ms/step - loss: 0.0555 - mse: 0.0555 - val_loss: 0.0648 - val_mse: 0.0648
# Epoch 25/50
# 136/136 [==============================] - 2s 14ms/step - loss: 0.0538 - mse: 0.0538 - val_loss: 0.0557 - val_mse: 0.0557
# Epoch 26/50
# 136/136 [==============================] - 2s 14ms/step - loss: 0.0508 - mse: 0.0508 - val_loss: 0.0593 - val_mse: 0.0593
# Epoch 27/50
# 136/136 [==============================] - 2s 18ms/step - loss: 0.0542 - mse: 0.0542 - val_loss: 0.0559 - val_mse: 0.0559
# Epoch 28/50
# 136/136 [==============================] - 2s 16ms/step - loss: 0.0518 - mse: 0.0518 - val_loss: 0.0553 - val_mse: 0.0553
# Epoch 29/50
# 136/136 [==============================] - 2s 15ms/step - loss: 0.0493 - mse: 0.0493 - val_loss: 0.0605 - val_mse: 0.0605
# Epoch 30/50
# 136/136 [==============================] - 2s 12ms/step - loss: 0.0512 - mse: 0.0512 - val_loss: 0.0543 - val_mse: 0.0543
# Epoch 31/50
# 136/136 [==============================] - 2s 15ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0500 - val_mse: 0.0500
# Epoch 32/50
# 136/136 [==============================] - 2s 14ms/step - loss: 0.0496 - mse: 0.0496 - val_loss: 0.0601 - val_mse: 0.0601
# Epoch 33/50
# 136/136 [==============================] - 2s 13ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0646 - val_mse: 0.0646
# Epoch 34/50
# 136/136 [==============================] - 2s 14ms/step - loss: 0.0475 - mse: 0.0475 - val_loss: 0.0557 - val_mse: 0.0557
# Epoch 35/50
# 136/136 [==============================] - 2s 15ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0626 - val_mse: 0.0626
# Epoch 36/50
# 136/136 [==============================] - 2s 11ms/step - loss: 0.0466 - mse: 0.0466 - val_loss: 0.0493 - val_mse: 0.0493
# Epoch 37/50
# 136/136 [==============================] - 2s 12ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0510 - val_mse: 0.0510
# Epoch 38/50
# 136/136 [==============================] - 2s 13ms/step - loss: 0.0471 - mse: 0.0471 - val_loss: 0.0538 - val_mse: 0.0538
# Epoch 39/50
# 136/136 [==============================] - 2s 12ms/step - loss: 0.0466 - mse: 0.0466 - val_loss: 0.0496 - val_mse: 0.0496
# Epoch 40/50
# 136/136 [==============================] - 2s 14ms/step - loss: 0.0460 - mse: 0.0460 - val_loss: 0.0484 - val_mse: 0.0484
# Epoch 41/50
# 136/136 [==============================] - 2s 13ms/step - loss: 0.0438 - mse: 0.0438 - val_loss: 0.0457 - val_mse: 0.0457
# Epoch 42/50
# 136/136 [==============================] - 2s 12ms/step - loss: 0.0450 - mse: 0.0450 - val_loss: 0.0472 - val_mse: 0.0472
# Epoch 43/50
# 136/136 [==============================] - 2s 12ms/step - loss: 0.0457 - mse: 0.0457 - val_loss: 0.0520 - val_mse: 0.0520
# Epoch 44/50
# 136/136 [==============================] - 2s 11ms/step - loss: 0.0466 - mse: 0.0466 - val_loss: 0.0522 - val_mse: 0.0522
# Epoch 45/50
# 136/136 [==============================] - 2s 11ms/step - loss: 0.0438 - mse: 0.0438 - val_loss: 0.0505 - val_mse: 0.0505
# Epoch 46/50
# 136/136 [==============================] - 2s 12ms/step - loss: 0.0424 - mse: 0.0424 - val_loss: 0.0550 - val_mse: 0.0550
# Epoch 47/50
# 136/136 [==============================] - 2s 11ms/step - loss: 0.0430 - mse: 0.0430 - val_loss: 0.0482 - val_mse: 0.0482
# Epoch 48/50
# 136/136 [==============================] - 2s 11ms/step - loss: 0.0468 - mse: 0.0468 - val_loss: 0.0489 - val_mse: 0.0489
# Epoch 49/50
# 136/136 [==============================] - 1s 11ms/step - loss: 0.0429 - mse: 0.0429 - val_loss: 0.0594 - val_mse: 0.0594
# Epoch 50/50
# 136/136 [==============================] - 1s 11ms/step - loss: 0.0428 - mse: 0.0428 - val_loss: 0.0457 - val_mse: 0.0457

# %%
[loss, mae] = model_conv1D.evaluate(X_test_reshaped, y_test, verbose=0)
print("Testing set Mean Abs Error: {:7.2f}".format(mae * 1000))

pred =model_conv1D.predict(X_test_reshaped)

y_pred_inv = scaler2.inverse_transform(y)


train_loss = history.history['loss']


val_loss = history.history['val_loss']


def plot_train_val(A, B, n, xlabel, ylabel, title):
    plt.figure(1, figsize=(10, 6))
    plt.plot(range(n),A)
    plt.plot(range(n),B)
    plt.ylabel(xlabel)
    plt.xlabel(ylabel)
    plt.title(title)
    plt.grid(True)
    plt.legend(['Training', 'Validation'])
    plt.show()


plot_train_val(train_loss, val_loss, ep, 'Loss', 'Number of epochs', 'Training loss vs Validation loss')
# Out:
# Testing set Mean Abs Error:   44.50

# %%
from sklearn.metrics import mean_absolute_error

# %%
a = scaler2.inverse_transform(pred)
print(a[:,0].shape)


b = scaler2.inverse_transform(y_test)
print(b[:,0].shape)

plt.figure()
plt.hist(a[:,0], label="pred")
plt.hist(b[:,0], label="test")

plt.legend(loc="best")
plt.show()
# Out:
# (543,)
# (543,)

# %%
pred[:,0].shape
# Out:
# (543,)

# %%
plt.figure()
plt.hist(a[:,1], label="pred")
plt.hist(b[:,1], label="test")

plt.legend(loc="best")
plt.show()

# %%
plt.figure()
plt.hist(a[:,2], label="pred")
plt.hist(b[:,2], label="test")

plt.legend(loc="best")
plt.show()

# %%
plt.figure()
plt.hist(pred[:,0], label="pred")
plt.hist(y_test[:,0], label="test")

plt.legend(loc="best")
plt.show()

# %%
plt.figure()
plt.hist(pred[:,1], label="pred")
plt.hist(y_test[:,1], label="test")

plt.legend(loc="best")
plt.show()

# %%
plt.figure()
plt.hist(y_test[:,2], label="test")
plt.hist(pred[:,2], label="pred")
plt.legend(loc="best")
plt.show()

# %%
mean_absolute_error(a, b)
# Out:
# 163.33154195916663

# %%
e_teff = abs(y_test[:,0] - pred[:,0])
e_logg = abs(y_test[:,1] - pred[:,1])
e_vrot = abs(y_test[:,2] - pred[:,2])

# %%
plt.figure()
plt.hist(e_teff)
plt.show()

# %%
plt.figure()
plt.hist(e_logg)
plt.show()

# %%
plt.figure()
plt.hist(e_vrot)
plt.show()

# %% [markdown]
# # BeSoS lines

# %%
df = pd.read_csv("BESOS/2_Be_stars/HD33328/PUCHEROS/hd33328_2013-02-26_00-55-34_final_corr.txt", sep="\t", header=None)

m1 = df[0] >= 4460
m2 = df[0] <= 4480

df2 = df[m1][m2]

df2
# Out:
# <ipython-input-35-82aaba16f6df>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df[m1][m2]
#                 0         1
# 2368  4460.008658  1.018850
# 2369  4460.097998  1.025028
# 2370  4460.187338  1.014237
# 2371  4460.276678  1.007267
# 2372  4460.366019  1.001199
# ...           ...       ...
# 2587  4479.574171  0.981866
# 2588  4479.663511  0.993424
# 2589  4479.752851  0.984521
# 2590  4479.842191  0.957564
# 2591  4479.931532  0.963475
#
# [224 rows x 2 columns]

# %%
plt.figure(figsize=(8,6))
plt.plot(df2[0], df2[1], label="Línea observada")
#plt.plot(df4[0], df4[1], label="Modelo")
plt.grid()
plt.legend(loc="best")
plt.show()

# %%
n = 201  # for 2 random indices
index = np.random.choice(df2[0].shape[0], n, replace=False)

# %%
index.sort()

# %%
obs_waves = df2[0].values[index]

obs_flux = df2[1].values[index]

# %%
obs_flux.shape
# Out:
# (201,)

# %%
#x_obs_inv= scaler.transform(obs_y.reshape(1,201))
y_obs_inv= scaler.transform(obs_flux.reshape(1,201))

# %%
plt.figure(figsize=(8,6))
plt.plot(obs_waves, y_obs_inv[0,:] ,label="Línea observada")
#plt.plot(df4[0], df4[1], label="Modelo")
plt.grid()
plt.legend(loc="best")
plt.show()

# %%
#obs_x_reshaped = x_obs_inv.reshape((1, time_steps, input_dimension))
#obs_x_reshaped = obs_x.reshape((1, time_steps, input_dimension))

obs_y_reshaped = y_obs_inv.reshape((1, time_steps, input_dimension))

# %%
pred_obs =model_conv1D.predict(obs_y_reshaped)

# %%
print("t_eff:", pred_obs[0][0])
print("log g:", pred_obs[0][1])
print("v_rot:", pred_obs[0][2])
# Out:
# t_eff: -0.6550577
# log g: 4.734293
# v_rot: 0.51432467

# %%
pred_obs_inv = scaler2.inverse_transform(pred_obs)

# %%
pred_obs_inv
# Out:
# array([[2.2276312e+04, 8.2342930e+00, 2.9600259e+02]], dtype=float32)

# %%
print(pred_obs_inv[0,0])
print(pred_obs_inv[0,1])
print(pred_obs_inv[0,2])
# Out:
# 22276.312
# 8.234293
# 296.0026
